# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# **Demographic/Administrative Data:**
# **subjectid :**  – A unique number for each participant measured in the anthropometric survey, ranging from 10027 to 920103, not inclusive
# **SubjectBirthLocation:** – Subject Birth Location; a U.S. state or foreign country
# **SubjectNumericRace:** – Subject Numeric Race; a single or multi-digit code indicating a subject’s self-reported race or races (verified through interview). Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian, 5 = Native American, 6 = Pacific Islander, 8 = Other
# **Ethnicity:** – self-reported ethnicity (verified through interview); e.g. “Mexican”, “Vietnamese”
# **DODRace:** – Department of Defense Race; a single digit indicating a subject’s self-reported preferred single race where selecting multiple races is not an option. This variable is intended to be comparable to the Defense Manpower Data Center demographic data. Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian, 5 = Native American, 6 = Pacific Islander, 8 = Other
# **Gender:** – “Male” or “Female”
# **Age:** – Participant’s age in years
# **Heightin:** – Height in Inches; self-reported, comparable to measured “stature”
# **Weightlbs:** – Weight in Pounds; self-reported, comparable to measured “weightkg”
# **WritingPreference – Writing Preference:** “Right hand”, “Left hand”, or “Either hand (No preference)”
# **Date:** – Date the participant was measured, ranging from “04-Oct-10” to “05-Apr-12”
# **Installation**: – U.S. Army installation where the measurement occurred; e.g. “Fort Hood”, “Camp Shelby”
# **Component:** – “Army National Guard”, “Army Reserve”, or “Regular Army”
# **Branch:** – “Combat Arms”, “Combat Support”, or “Combat Service Support”
# **PrimaryMOS:** – Primary Military Occupational Specialty

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (7,4)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
#pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
df1 = pd.read_csv("ANSUR II FEMALE Public.csv")

# %%
df2 = pd.read_csv("ANSUR II MALE Public.csv", encoding='ISO-8859-1')

# %% [markdown]
# ## Explore Data

# %%
df1.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  ...                  Branch  PrimaryMOS  \
# 0                        315  ...          Combat Support         92Y
# 1                        272  ...  Combat Service Support         25U
# 2                        300  ...  Combat Service Support         35D
# 3                        364  ...  Combat Service Support         25U
# 4                        320  ...             Combat Arms         42A
#
#    SubjectsBirthLocation  SubjectNumericRace           Ethnicity  DODRace  \
# 0                Germany                   2                 NaN        2
# 1             California                   3             Mexican        3
# 2                  Texas                   1                 NaN        1
# 3   District of Columbia                   8  Caribbean Islander        2
# 4                  Texas                   1                 NaN        1
#
#    Age  Heightin  Weightlbs  WritingPreference
# 0   26        61        142         Right hand
# 1   21        64        120         Right hand
# 2   23        68        147         Right hand
# 3   22        66        175         Right hand
# 4   45        63        195         Right hand
#
# [5 rows x 108 columns]

# %%
df1.shape
# Out:
# (1986, 108)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Columns: 108 entries, SubjectId to WritingPreference
# dtypes: int64(99), object(9)
# memory usage: 1.6+ MB

# %%
df1.columns
# Out:
# Index(['SubjectId', 'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed',
#        ...
#        'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace',
#        'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs',
#        'WritingPreference'],
#       dtype='object', length=108)

# %%
df1.isnull().sum()
# Out:
# SubjectId                         0
# abdominalextensiondepthsitting    0
# acromialheight                    0
# acromionradialelength             0
# anklecircumference                0
#                                  ..
# DODRace                           0
# Age                               0
# Heightin                          0
# Weightlbs                         0
# WritingPreference                 0
# Length: 108, dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df2.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  ...                  Branch  PrimaryMOS  \
# 0                        369  ...             Combat Arms         19D
# 1                        338  ...          Combat Support         68W
# 2                        408  ...          Combat Support         68W
# 3                        359  ...  Combat Service Support         88M
# 4                        356  ...  Combat Service Support         92G
#
#    SubjectsBirthLocation  SubjectNumericRace  Ethnicity  DODRace  Age  \
# 0           North Dakota                   1        NaN        1   41
# 1               New York                   1        NaN        1   35
# 2               New York                   2        NaN        2   42
# 3              Wisconsin                   1        NaN        1   31
# 4         North Carolina                   2        NaN        2   21
#
#    Heightin  Weightlbs  WritingPreference
# 0        71        180         Right hand
# 1        68        160          Left hand
# 2        68        205          Left hand
# 3        66        175         Right hand
# 4        77        213         Right hand
#
# [5 rows x 108 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4082 entries, 0 to 4081
# Columns: 108 entries, subjectid to WritingPreference
# dtypes: int64(99), object(9)
# memory usage: 3.4+ MB

# %%
df2.columns
# Out:
# Index(['subjectid', 'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed',
#        ...
#        'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace',
#        'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs',
#        'WritingPreference'],
#       dtype='object', length=108)

# %%
df2.isnull().sum()
# Out:
# subjectid                         0
# abdominalextensiondepthsitting    0
# acromialheight                    0
# acromionradialelength             0
# anklecircumference                0
#                                  ..
# DODRace                           0
# Age                               0
# Heightin                          0
# Weightlbs                         0
# WritingPreference                 0
# Length: 108, dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.shape
# Out:
# (4082, 108)

# %%
df = df1.append(df2)

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.shape
# Out:
# (6068, 109)

# %%
df.info(verbose=True) ## shows all  columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 109 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    SubjectId                       float64
#  1    abdominalextensiondepthsitting  int64
#  2    acromialheight                  int64
#  3    acromionradialelength           int64
#  4    anklecircumference              int64
#  5    axillaheight                    int64
#  6    balloffootcircumference         int64
#  7    balloffootlength                int64
#  8    biacromialbreadth               int64
#  9    bicepscircumferenceflexed       int64
#  10   bicristalbreadth                int64
#  11   bideltoidbreadth                int64
#  12   bimalleolarbreadth              int64
#  13   bitragionchinarc                int64
#  14   bitragionsubmandibulararc       int64
#  15   bizygomaticbreadth              int64
#  16   buttockcircumference            int64
#  17   buttockdepth                    int64
#  18   buttockheight                   int64
#  19   buttockkneelength               int64
#  20   buttockpopliteallength          int64
#  21   calfcircumference               int64
#  22   cervicaleheight                 int64
#  23   chestbreadth                    int64
#  24   chestcircumference              int64
#  25   chestdepth                      int64
#  26   chestheight                     int64
#  27   crotchheight                    int64
#  28   crotchlengthomphalion           int64
#  29   crotchlengthposterioromphalion  int64
#  30   earbreadth                      int64
#  31   earlength                       int64
#  32   earprotrusion                   int64
#  33   elbowrestheight                 int64
#  34   eyeheightsitting                int64
#  35   footbreadthhorizontal           int64
#  36   footlength                      int64
#  37   forearmcenterofgriplength       int64
#  38   forearmcircumferenceflexed      int64
#  39   forearmforearmbreadth           int64
#  40   forearmhandlength               int64
#  41   functionalleglength             int64
#  42   handbreadth                     int64
#  43   handcircumference               int64
#  44   handlength                      int64
#  45   headbreadth                     int64
#  46   headcircumference               int64
#  47   headlength                      int64
#  48   heelanklecircumference          int64
#  49   heelbreadth                     int64
#  50   hipbreadth                      int64
#  51   hipbreadthsitting               int64
#  52   iliocristaleheight              int64
#  53   interpupillarybreadth           int64
#  54   interscyei                      int64
#  55   interscyeii                     int64
#  56   kneeheightmidpatella            int64
#  57   kneeheightsitting               int64
#  58   lateralfemoralepicondyleheight  int64
#  59   lateralmalleolusheight          int64
#  60   lowerthighcircumference         int64
#  61   mentonsellionlength             int64
#  62   neckcircumference               int64
#  63   neckcircumferencebase           int64
#  64   overheadfingertipreachsitting   int64
#  65   palmlength                      int64
#  66   poplitealheight                 int64
#  67   radialestylionlength            int64
#  68   shouldercircumference           int64
#  69   shoulderelbowlength             int64
#  70   shoulderlength                  int64
#  71   sittingheight                   int64
#  72   sleevelengthspinewrist          int64
#  73   sleeveoutseam                   int64
#  74   span                            int64
#  75   stature                         int64
#  76   suprasternaleheight             int64
#  77   tenthribheight                  int64
#  78   thighcircumference              int64
#  79   thighclearance                  int64
#  80   thumbtipreach                   int64
#  81   tibialheight                    int64
#  82   tragiontopofhead                int64
#  83   trochanterionheight             int64
#  84   verticaltrunkcircumferenceusa   int64
#  85   waistbacklength                 int64
#  86   waistbreadth                    int64
#  87   waistcircumference              int64
#  88   waistdepth                      int64
#  89   waistfrontlengthsitting         int64
#  90   waistheightomphalion            int64
#  91   weightkg                        int64
#  92   wristcircumference              int64
#  93   wristheight                     int64
#  94   Gender                          object
#  95   Date                            object
#  96   Installation                    object
#  97   Component                       object
#  98   Branch                          object
#  99   PrimaryMOS                      object
#  100  SubjectsBirthLocation           object
#  101  SubjectNumericRace              int64
#  102  Ethnicity                       object
#  103  DODRace                         int64
#  104  Age                             int64
#  105  Heightin                        int64
#  106  Weightlbs                       int64
#  107  WritingPreference               object
#  108  subjectid                       float64
# dtypes: float64(2), int64(98), object(9)
# memory usage: 5.0+ MB

# %%
df.isnull().sum()
# Out:
# SubjectId                         4082
# abdominalextensiondepthsitting       0
# acromialheight                       0
# acromionradialelength                0
# anklecircumference                   0
#                                   ...
# Age                                  0
# Heightin                             0
# Weightlbs                            0
# WritingPreference                    0
# subjectid                         1986
# Length: 109, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[["SubjectId","subjectid"]]
# Out:
#       SubjectId  subjectid
# 0       10037.0        NaN
# 1       10038.0        NaN
# 2       10042.0        NaN
# 3       10043.0        NaN
# 4       10051.0        NaN
# ...         ...        ...
# 6063        NaN    29442.0
# 6064        NaN    29443.0
# 6065        NaN    29447.0
# 6066        NaN    29451.0
# 6067        NaN    29452.0
#
# [6068 rows x 2 columns]

# %%
df.drop("subjectid", axis = 1, inplace = True)

# %%
df.drop("SubjectId", axis = 1, inplace = True)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 107 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    abdominalextensiondepthsitting  int64
#  1    acromialheight                  int64
#  2    acromionradialelength           int64
#  3    anklecircumference              int64
#  4    axillaheight                    int64
#  5    balloffootcircumference         int64
#  6    balloffootlength                int64
#  7    biacromialbreadth               int64
#  8    bicepscircumferenceflexed       int64
#  9    bicristalbreadth                int64
#  10   bideltoidbreadth                int64
#  11   bimalleolarbreadth              int64
#  12   bitragionchinarc                int64
#  13   bitragionsubmandibulararc       int64
#  14   bizygomaticbreadth              int64
#  15   buttockcircumference            int64
#  16   buttockdepth                    int64
#  17   buttockheight                   int64
#  18   buttockkneelength               int64
#  19   buttockpopliteallength          int64
#  20   calfcircumference               int64
#  21   cervicaleheight                 int64
#  22   chestbreadth                    int64
#  23   chestcircumference              int64
#  24   chestdepth                      int64
#  25   chestheight                     int64
#  26   crotchheight                    int64
#  27   crotchlengthomphalion           int64
#  28   crotchlengthposterioromphalion  int64
#  29   earbreadth                      int64
#  30   earlength                       int64
#  31   earprotrusion                   int64
#  32   elbowrestheight                 int64
#  33   eyeheightsitting                int64
#  34   footbreadthhorizontal           int64
#  35   footlength                      int64
#  36   forearmcenterofgriplength       int64
#  37   forearmcircumferenceflexed      int64
#  38   forearmforearmbreadth           int64
#  39   forearmhandlength               int64
#  40   functionalleglength             int64
#  41   handbreadth                     int64
#  42   handcircumference               int64
#  43   handlength                      int64
#  44   headbreadth                     int64
#  45   headcircumference               int64
#  46   headlength                      int64
#  47   heelanklecircumference          int64
#  48   heelbreadth                     int64
#  49   hipbreadth                      int64
#  50   hipbreadthsitting               int64
#  51   iliocristaleheight              int64
#  52   interpupillarybreadth           int64
#  53   interscyei                      int64
#  54   interscyeii                     int64
#  55   kneeheightmidpatella            int64
#  56   kneeheightsitting               int64
#  57   lateralfemoralepicondyleheight  int64
#  58   lateralmalleolusheight          int64
#  59   lowerthighcircumference         int64
#  60   mentonsellionlength             int64
#  61   neckcircumference               int64
#  62   neckcircumferencebase           int64
#  63   overheadfingertipreachsitting   int64
#  64   palmlength                      int64
#  65   poplitealheight                 int64
#  66   radialestylionlength            int64
#  67   shouldercircumference           int64
#  68   shoulderelbowlength             int64
#  69   shoulderlength                  int64
#  70   sittingheight                   int64
#  71   sleevelengthspinewrist          int64
#  72   sleeveoutseam                   int64
#  73   span                            int64
#  74   stature                         int64
#  75   suprasternaleheight             int64
#  76   tenthribheight                  int64
#  77   thighcircumference              int64
#  78   thighclearance                  int64
#  79   thumbtipreach                   int64
#  80   tibialheight                    int64
#  81   tragiontopofhead                int64
#  82   trochanterionheight             int64
#  83   verticaltrunkcircumferenceusa   int64
#  84   waistbacklength                 int64
#  85   waistbreadth                    int64
#  86   waistcircumference              int64
#  87   waistdepth                      int64
#  88   waistfrontlengthsitting         int64
#  89   waistheightomphalion            int64
#  90   weightkg                        int64
#  91   wristcircumference              int64
#  92   wristheight                     int64
#  93   Gender                          object
#  94   Date                            object
#  95   Installation                    object
#  96   Component                       object
#  97   Branch                          object
#  98   PrimaryMOS                      object
#  99   SubjectsBirthLocation           object
#  100  SubjectNumericRace              int64
#  101  Ethnicity                       object
#  102  DODRace                         int64
#  103  Age                             int64
#  104  Heightin                        int64
#  105  Weightlbs                       int64
#  106  WritingPreference               object
# dtypes: int64(98), object(9)
# memory usage: 5.0+ MB

# %%
df.columns =  df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed', 'bicristalbreadth',
#        ...
#        'branch', 'primarymos', 'subjectsbirthlocation', 'subjectnumericrace',
#        'ethnicity', 'dodrace', 'age', 'heightin', 'weightlbs',
#        'writingpreference'],
#       dtype='object', length=107)

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 107 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    abdominalextensiondepthsitting  int64
#  1    acromialheight                  int64
#  2    acromionradialelength           int64
#  3    anklecircumference              int64
#  4    axillaheight                    int64
#  5    balloffootcircumference         int64
#  6    balloffootlength                int64
#  7    biacromialbreadth               int64
#  8    bicepscircumferenceflexed       int64
#  9    bicristalbreadth                int64
#  10   bideltoidbreadth                int64
#  11   bimalleolarbreadth              int64
#  12   bitragionchinarc                int64
#  13   bitragionsubmandibulararc       int64
#  14   bizygomaticbreadth              int64
#  15   buttockcircumference            int64
#  16   buttockdepth                    int64
#  17   buttockheight                   int64
#  18   buttockkneelength               int64
#  19   buttockpopliteallength          int64
#  20   calfcircumference               int64
#  21   cervicaleheight                 int64
#  22   chestbreadth                    int64
#  23   chestcircumference              int64
#  24   chestdepth                      int64
#  25   chestheight                     int64
#  26   crotchheight                    int64
#  27   crotchlengthomphalion           int64
#  28   crotchlengthposterioromphalion  int64
#  29   earbreadth                      int64
#  30   earlength                       int64
#  31   earprotrusion                   int64
#  32   elbowrestheight                 int64
#  33   eyeheightsitting                int64
#  34   footbreadthhorizontal           int64
#  35   footlength                      int64
#  36   forearmcenterofgriplength       int64
#  37   forearmcircumferenceflexed      int64
#  38   forearmforearmbreadth           int64
#  39   forearmhandlength               int64
#  40   functionalleglength             int64
#  41   handbreadth                     int64
#  42   handcircumference               int64
#  43   handlength                      int64
#  44   headbreadth                     int64
#  45   headcircumference               int64
#  46   headlength                      int64
#  47   heelanklecircumference          int64
#  48   heelbreadth                     int64
#  49   hipbreadth                      int64
#  50   hipbreadthsitting               int64
#  51   iliocristaleheight              int64
#  52   interpupillarybreadth           int64
#  53   interscyei                      int64
#  54   interscyeii                     int64
#  55   kneeheightmidpatella            int64
#  56   kneeheightsitting               int64
#  57   lateralfemoralepicondyleheight  int64
#  58   lateralmalleolusheight          int64
#  59   lowerthighcircumference         int64
#  60   mentonsellionlength             int64
#  61   neckcircumference               int64
#  62   neckcircumferencebase           int64
#  63   overheadfingertipreachsitting   int64
#  64   palmlength                      int64
#  65   poplitealheight                 int64
#  66   radialestylionlength            int64
#  67   shouldercircumference           int64
#  68   shoulderelbowlength             int64
#  69   shoulderlength                  int64
#  70   sittingheight                   int64
#  71   sleevelengthspinewrist          int64
#  72   sleeveoutseam                   int64
#  73   span                            int64
#  74   stature                         int64
#  75   suprasternaleheight             int64
#  76   tenthribheight                  int64
#  77   thighcircumference              int64
#  78   thighclearance                  int64
#  79   thumbtipreach                   int64
#  80   tibialheight                    int64
#  81   tragiontopofhead                int64
#  82   trochanterionheight             int64
#  83   verticaltrunkcircumferenceusa   int64
#  84   waistbacklength                 int64
#  85   waistbreadth                    int64
#  86   waistcircumference              int64
#  87   waistdepth                      int64
#  88   waistfrontlengthsitting         int64
#  89   waistheightomphalion            int64
#  90   weightkg                        int64
#  91   wristcircumference              int64
#  92   wristheight                     int64
#  93   gender                          object
#  94   date                            object
#  95   installation                    object
#  96   component                       object
#  97   branch                          object
#  98   primarymos                      object
#  99   subjectsbirthlocation           object
#  100  subjectnumericrace              int64
#  101  ethnicity                       object
#  102  dodrace                         int64
#  103  age                             int64
#  104  heightin                        int64
#  105  weightlbs                       int64
#  106  writingpreference               object
# dtypes: int64(98), object(9)
# memory usage: 5.0+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include = "O").T
# Out:
#                       count unique                     top  freq
# gender                 6068      2                    Male  4082
# date                   6068    253               27-Feb-12    45
# installation           6068     12             Camp Shelby  1160
# component              6068      3            Regular Army  3140
# branch                 6068      3  Combat Service Support  3174
# primarymos             6068    285                     11B   671
# subjectsbirthlocation  6068    152              California   446
# ethnicity              1421    209                 Mexican   357
# writingpreference      6068      3              Right hand  5350

# %%
df.describe().T
# Out:
#                                  count         mean         std     min  \
# abdominalextensiondepthsitting  6068.0   246.468688   37.400106   155.0
# acromialheight                  6068.0  1406.161338   79.091048  1115.0
# acromionradialelength           6068.0   327.374423   20.720018   249.0
# anklecircumference              6068.0   224.891397   16.051833   156.0
# axillaheight                    6068.0  1299.608767   72.022286  1038.0
# ...                                ...          ...         ...     ...
# subjectnumericrace              6068.0    17.515326  550.949948     1.0
# dodrace                         6068.0     1.615030    0.979156     1.0
# age                             6068.0    29.761206    8.674650    17.0
# heightin                        6068.0    68.257251    3.861954    56.0
# weightlbs                       6068.0   174.749670   33.691952     0.0
#
#                                    25%     50%      75%      max
# abdominalextensiondepthsitting   219.0   242.0   271.00    451.0
# acromialheight                  1350.0  1410.0  1462.00   1683.0
# acromionradialelength            313.0   328.0   341.25    393.0
# anklecircumference               214.0   225.0   235.00    293.0
# axillaheight                    1249.0  1302.0  1349.00   1553.0
# ...                                ...     ...      ...      ...
# subjectnumericrace                 1.0     1.0     2.00  42351.0
# dodrace                            1.0     1.0     2.00      8.0
# age                               23.0    28.0    36.00     58.0
# heightin                          66.0    68.0    71.00     94.0
# weightlbs                        150.0   173.0   196.00    321.0
#
# [98 rows x 8 columns]

# %%
def count_missing_values(df):
    missing_values = df.isnull().sum()
    return missing_values

# %%
def missing_value_percent(df):
    null_counts = df.isnull().sum()
    total_counts = df.isnull().count()
    missing_ratios = round(null_counts / total_counts * 100, 2)
    return missing_ratios

# %%
count_missing_values(df)
# Out:
# abdominalextensiondepthsitting    0
# acromialheight                    0
# acromionradialelength             0
# anklecircumference                0
# axillaheight                      0
#                                  ..
# dodrace                           0
# age                               0
# heightin                          0
# weightlbs                         0
# writingpreference                 0
# Length: 107, dtype: int64

# %%
missing_value_percent(df)
# Out:
# abdominalextensiondepthsitting    0.0
# acromialheight                    0.0
# acromionradialelength             0.0
# anklecircumference                0.0
# axillaheight                      0.0
#                                  ...
# dodrace                           0.0
# age                               0.0
# heightin                          0.0
# weightlbs                         0.0
# writingpreference                 0.0
# Length: 107, dtype: float64

# %% [markdown]
# ## Dodrace

# %% [markdown]
# Department of Defense Race; a single digit indicating a subject’s self-reported preferred single race where selecting multiple races is not an option. This variable is intended to be comparable to the Defense Manpower Data Center demographic data. Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian, 5 = Native American, 6 = Pacific Islander, 8 = Other

# %%
df.dodrace.value_counts(dropna = False)
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: dodrace, dtype: int64

# %%
## Dropping dodrace < 500

# %%
df.drop(df[df['dodrace']==4].index, inplace = True)
df.drop(df[df['dodrace']==6].index, inplace = True)
df.drop(df[df['dodrace']==5].index, inplace = True)
df.drop(df[df['dodrace']==8].index, inplace = True)

# %%
df.dodrace.value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# Name: dodrace, dtype: int64

# %%
sns.boxplot(x = "dodrace",data = df);

# %%
df["dodrace"] = df.dodrace.map({
    1: "White",
    2: "Black",
    3: "Hispanic"
})

# %%
fig, ax = plt.subplots()
ax.pie(df.dodrace.value_counts(), labels=df.dodrace.value_counts().index, autopct='%1.1f%%')
ax.legend(df.dodrace.value_counts().index, title="dodrace", loc="lower left")
plt.show()

# %%
ax = df.dodrace.value_counts().plot(kind="bar")
ax.set_xlabel("dodrace")
ax.set_ylabel("Count")
ax.set_title("dodrace value counts")
for i, v in enumerate(df.dodrace.value_counts()):
    ax.text(i - 0.1, v + 0.5, str(v))
plt.show()

# %%
df.dodrace.value_counts()
# Out:
# White       3792
# Black       1298
# Hispanic     679
# Name: dodrace, dtype: int64

# %%
object_cols = df.select_dtypes("object")
object_cols
# Out:
#       gender      date installation            component  \
# 0     Female  5-Oct-10    Fort Hood         Regular Army
# 1     Female  5-Oct-10    Fort Hood         Regular Army
# 2     Female  5-Oct-10    Fort Hood         Regular Army
# 3     Female  5-Oct-10    Fort Hood         Regular Army
# 4     Female  5-Oct-10    Fort Hood         Regular Army
# ...      ...       ...          ...                  ...
# 6063    Male  4-Apr-12  Camp Shelby  Army National Guard
# 6064    Male  4-Apr-12  Camp Shelby  Army National Guard
# 6065    Male  4-Apr-12  Camp Shelby  Army National Guard
# 6066    Male  4-Apr-12  Camp Shelby  Army National Guard
# 6067    Male  4-Apr-12  Camp Shelby  Army National Guard
#
#                       branch primarymos subjectsbirthlocation  \
# 0             Combat Support        92Y               Germany
# 1     Combat Service Support        25U            California
# 2     Combat Service Support        35D                 Texas
# 3     Combat Service Support        25U  District of Columbia
# 4                Combat Arms        42A                 Texas
# ...                      ...        ...                   ...
# 6063             Combat Arms        11B              Colorado
# 6064             Combat Arms        91B              Oklahoma
# 6065             Combat Arms        13B              Oklahoma
# 6066             Combat Arms        13P              Oklahoma
# 6067             Combat Arms        92Y              Oklahoma
#
#                        ethnicity   dodrace writingpreference
# 0                            NaN     Black        Right hand
# 1                        Mexican  Hispanic        Right hand
# 2                            NaN     White        Right hand
# 3             Caribbean Islander     Black        Right hand
# 4                            NaN     White        Right hand
# ...                          ...       ...               ...
# 6063  Blackfoot Cherokee Choctaw     White        Right hand
# 6064                         NaN     White        Right hand
# 6065                         NaN     White        Right hand
# 6066                         NaN     White        Right hand
# 6067                         NaN     White        Right hand
#
# [5769 rows x 10 columns]

# %% [markdown]
# ## Ethnicity

# %% [markdown]
# self-reported ethnicity (verified through interview); e.g. “Mexican”, “Vietnamese”

# %%
df.ethnicity.value_counts(dropna = False)
# Out:
# NaN                                  4644
# Mexican                               356
# Puerto Rican                          183
# Caribbean Islander                    123
# Cherokee                               60
#                                      ...
# Chinese Vietnamese                      1
# Undisclosed Native American Tribe       1
# Cherokee Yaqui                          1
# Aztec Mexican                           1
# Blackfoot Cherokee Choctaw              1
# Name: ethnicity, Length: 158, dtype: int64

# %%
df.ethnicity.unique()
# Out:
# array([nan, 'Mexican', 'Caribbean Islander', 'Dominican', 'Cherokee',
#        'Puerto Rican', 'Cochiti Pueblo Mexican',
#        'Algonquin Navajo Penobscot', 'Chilean Mexican', 'Nicaraguan',
#        'Arab or Middle Eastern', 'Argentine', 'Peruvian',
#        'Belizean Dominican', 'Cuban Mexican', 'Apache Cherokee',
#        'Comanche', 'Honduran', 'Korean', 'Ecuadorian',
#        'Cherokee Puerto Rican', 'Salvadoran', 'Puerto Rican Seneca',
#        'Cuban Puerto Rican', 'Samoan',
#        'Arab or Middle Eastern Venezuelan', 'Bolivian', 'Potawatomi',
#        'Cherokee Choctaw Mexican', 'Thai', 'Blackfoot Cherokee',
#        'Honduran Panamanian', 'Seminole', 'Brazilian', 'Cuban',
#        'Caribbean Islander Chinese East/Asian Indian',
#        'Cherokee Hawaiian', 'Filipino', 'Ecuadorian Puerto Rican',
#        'Panamanian', 'Choctaw Cherokee', 'Colombian', 'Chippewa',
#        'Paraguayan', 'Chilean', 'Blackfoot', 'Cherokee Mexican',
#        'Dominican Puerto Rican', 'Guamanian/Chamorro', 'Muscogee',
#        'Japanese', 'Japanese Mexican', 'Filipino Mexican',
#        'Puerto Rican Vietnamese', 'East/Asian Indian',
#        'Mexican Puerto Rican', 'Mexican Venezuelan', 'Sri Lankan',
#        'Caribbean Islander Puerto Rican', 'Mexican Salvadoran',
#        'Cherokee Sioux', 'Guatemalan Mexican', 'Hawaiian Polynesian',
#        'Creek', 'Chippewa Narragansett',
#        'Arab or Middle Eastern Caribbean Islander Cherokee', 'Cheyenne',
#        'Blackfoot Puerto Rican', 'Peruvian Salvadoran',
#        'Cuban Venezuelan', 'Lenape Puerto Rican', 'Guatemalan',
#        'Aztec Mexican', 'Cherokee Choctaw', 'Cherokee Yaqui',
#        'Undisclosed Native American Tribe', 'Chinese Vietnamese', 'Cree',
#        'Choctaw', 'Chinese Puerto Rican Seminole',
#        'Apache Blackfoot Cherokee Crow', 'Mexican Yaqui',
#        'Nicaraguan Salvadoran', 'Arab or Middle Eastern Honduran',
#        'Honduran Nicaraguan', 'Mexican Turkish', 'Apache', 'Turkish',
#        'Azorean', 'Costa Rican Salvadoran', 'Guatemalan Honduran',
#        'Houma', 'Mexican Pima', 'Mescalero Apache', 'Aboriginal Guyanese',
#        'Mexican Nicaraguan', 'Navajo', 'Lumbee', 'Salvadoran Venezuelan',
#        'Caribbean Islander East/Asian Indian', 'Shawnee',
#        'Argentine Mexican', 'Belizean', 'Cherokee Iroquois',
#        'Dominican Guyanese', 'Sioux', 'Argentine Brazilian',
#        'Cherokee Korean', 'Cape Verdean', 'Cherokee Comanche',
#        'Guatemalan Puerto Rican', 'Caribbean Islander Panamanian',
#        'Dominican Korean', 'Hunkpapa Lakota', 'Kiowa', 'Mexican Zuni',
#        'Ojibwe', 'Chinese', 'Ute',
#        'Cuban Unreadable Native American Tribe',
#        'Panamanian Puerto Rican',
#        'Blackfoot Caribbean Islander Puerto Rican', 'Costa Rican Cuban',
#        'Blackfoot Choctaw Sioux', 'Apache Kiowa Mexican', 'Chinook',
#        'Chippewa Mexican', 'Colombian Ecuadorian', 'Apache Blackfoot',
#        'Indonesian Puerto Rican', 'Caribbean Islander Dominican',
#        'Cuban Salvadoran', 'Blackfoot Mexican', 'Hmong', 'Costa Rican',
#        'Colombian Puerto Rican', 'Mexican Panamanian', 'Cherokee Osage',
#        'Cherokee Japanese', 'Hawaiian', 'Vietnamese', 'Cuban Laotian',
#        'Malaysian', 'Dominican Ecuadorian Puerto Rican',
#        'Arab or Middle Eastern Cuban', 'Caribbean Islander Cuban',
#        'Armenian', 'Miami', 'Caribbean Islander Cherokee',
#        'Dominican Salvadoran', 'Colombian Cuban', 'Blackfoot Shawnee',
#        'Choctaw Sioux', 'Guatemalan Salvadoran', 'Western Cherokee',
#        'Chickasaw', 'Chickasaw Choctaw', 'Blackfoot Cherokee Choctaw'],
#       dtype=object)

# %%
df.ethnicity.isnull().sum()
# Out:
# 4644

# %%
## There are so many nulls. And other values are meaningless. So i dropped the column.

# %%
df. drop("ethnicity", axis = 1, inplace = True)

# %% [markdown]
# ## Subjects Birth Location

# %% [markdown]
# Subject Birth Location; a U.S. state or foreign country

# %%
df.subjectsbirthlocation.value_counts()
# Out:
# California                417
# New York                  411
# Texas                     386
# Indiana                   264
# Illinois                  210
#                          ...
# Bosnia and Herzegovina      1
# Bermuda                     1
# Denmark                     1
# South Korea                 1
# Guatemala                   1
# Name: subjectsbirthlocation, Length: 136, dtype: int64

# %% [markdown]
# ## Date

# %% [markdown]
# Date the participant was measured, ranging from “04-Oct-10” to “05-Apr-12”.So we dont need this column.

# %%
df. drop("date", axis = 1, inplace = True)

# %% [markdown]
# ## Installation

# %% [markdown]
# U.S. Army installation where the measurement occurred; e.g. “Fort Hood”, “Camp Shelby”

# %%
df.installation.value_counts(dropna = False)
# Out:
# Camp Shelby       1111
# Fort Bliss         925
# Fort Gordon        636
# Camp Atterbury     432
# Fort McCoy         432
# Fort Hood          416
# Fort Huachuca      404
# Fort Bragg         373
# Fort Drum          369
# Fort Lee           356
# Fort Stewart       314
# Fort Rucker          1
# Name: installation, dtype: int64

# %%
## I think installation place is not important. So i drop this column.

# %%
df.drop("installation", axis = 1, inplace = True)

# %%
df.select_dtypes("object")
# Out:
#       gender            component                  branch primarymos  \
# 0     Female         Regular Army          Combat Support        92Y
# 1     Female         Regular Army  Combat Service Support        25U
# 2     Female         Regular Army  Combat Service Support        35D
# 3     Female         Regular Army  Combat Service Support        25U
# 4     Female         Regular Army             Combat Arms        42A
# ...      ...                  ...                     ...        ...
# 6063    Male  Army National Guard             Combat Arms        11B
# 6064    Male  Army National Guard             Combat Arms        91B
# 6065    Male  Army National Guard             Combat Arms        13B
# 6066    Male  Army National Guard             Combat Arms        13P
# 6067    Male  Army National Guard             Combat Arms        92Y
#
#      subjectsbirthlocation   dodrace writingpreference
# 0                  Germany     Black        Right hand
# 1               California  Hispanic        Right hand
# 2                    Texas     White        Right hand
# 3     District of Columbia     Black        Right hand
# 4                    Texas     White        Right hand
# ...                    ...       ...               ...
# 6063              Colorado     White        Right hand
# 6064              Oklahoma     White        Right hand
# 6065              Oklahoma     White        Right hand
# 6066              Oklahoma     White        Right hand
# 6067              Oklahoma     White        Right hand
#
# [5769 rows x 7 columns]

# %% [markdown]
# ## Component

# %% [markdown]
# “Army National Guard”, “Army Reserve”, or “Regular Army”

# %%
df.component.value_counts(dropna = False)
# Out:
# Regular Army           2955
# Army National Guard    2607
# Army Reserve            207
# Name: component, dtype: int64

# %%
df.groupby(["component"])["dodrace"].value_counts(normalize=True)
# Out:
# component            dodrace
# Army National Guard  White       0.711546
#                      Black       0.191408
#                      Hispanic    0.097046
# Army Reserve         White       0.550725
#                      Black       0.251208
#                      Hispanic    0.198068
# Regular Army         White       0.616920
#                      Black       0.252792
#                      Hispanic    0.130288
# Name: dodrace, dtype: float64

# %%
grouped_df = df.groupby(["component"])["dodrace"].value_counts(normalize=True).reset_index(name="percentage")
ax = sns.barplot(x="component", y="percentage", hue="dodrace", data=grouped_df)
for p in ax.containers:
    ax.bar_label(p, label_type="edge", fontsize=8)
plt.show()

# %%
##Which component a person works on is not important in determining race. 
##Therefore, this column should also be dropped.

# %%
df.drop("component", axis = 1, inplace = True)

# %%
df.select_dtypes("object")
# Out:
#       gender                  branch primarymos subjectsbirthlocation  \
# 0     Female          Combat Support        92Y               Germany
# 1     Female  Combat Service Support        25U            California
# 2     Female  Combat Service Support        35D                 Texas
# 3     Female  Combat Service Support        25U  District of Columbia
# 4     Female             Combat Arms        42A                 Texas
# ...      ...                     ...        ...                   ...
# 6063    Male             Combat Arms        11B              Colorado
# 6064    Male             Combat Arms        91B              Oklahoma
# 6065    Male             Combat Arms        13B              Oklahoma
# 6066    Male             Combat Arms        13P              Oklahoma
# 6067    Male             Combat Arms        92Y              Oklahoma
#
#        dodrace writingpreference
# 0        Black        Right hand
# 1     Hispanic        Right hand
# 2        White        Right hand
# 3        Black        Right hand
# 4        White        Right hand
# ...        ...               ...
# 6063     White        Right hand
# 6064     White        Right hand
# 6065     White        Right hand
# 6066     White        Right hand
# 6067     White        Right hand
#
# [5769 rows x 6 columns]

# %% [markdown]
# ## Branch

# %% [markdown]
# “Combat Arms”, “Combat Support”, or “Combat Service Support”

# %%
df.branch.value_counts(dropna = False)
# Out:
# Combat Service Support    3021
# Combat Arms               1508
# Combat Support            1240
# Name: branch, dtype: int64

# %%
df.groupby(["branch"])["dodrace"].value_counts(normalize=True)
# Out:
# branch                  dodrace
# Combat Arms             White       0.759947
#                         Hispanic    0.125332
#                         Black       0.114721
# Combat Service Support  White       0.632572
#                         Black       0.246607
#                         Hispanic    0.120821
# Combat Support          White       0.592742
#                         Black       0.306452
#                         Hispanic    0.100806
# Name: dodrace, dtype: float64

# %%
grouped_df = df.groupby(["branch"])["dodrace"].value_counts(normalize=True).reset_index(name="percentage")
ax = sns.barplot(x="branch", y="percentage", hue="dodrace", data=grouped_df)
for p in ax.containers:
    ax.bar_label(p, label_type="edge", fontsize=8)
plt.show()

# %%
##Which branch a person works on is not important in determining race. 
##Therefore, this column should also be dropped.

# %%
df.drop("branch", axis = 1, inplace = True)

# %%
df.select_dtypes("object")
# Out:
#       gender primarymos subjectsbirthlocation   dodrace writingpreference
# 0     Female        92Y               Germany     Black        Right hand
# 1     Female        25U            California  Hispanic        Right hand
# 2     Female        35D                 Texas     White        Right hand
# 3     Female        25U  District of Columbia     Black        Right hand
# 4     Female        42A                 Texas     White        Right hand
# ...      ...        ...                   ...       ...               ...
# 6063    Male        11B              Colorado     White        Right hand
# 6064    Male        91B              Oklahoma     White        Right hand
# 6065    Male        13B              Oklahoma     White        Right hand
# 6066    Male        13P              Oklahoma     White        Right hand
# 6067    Male        92Y              Oklahoma     White        Right hand
#
# [5769 rows x 5 columns]

# %% [markdown]
# ## Primary MOS

# %% [markdown]
# Primary Military Occupational Specialty

# %%
df.primarymos.value_counts(dropna = False)
# Out:
# 11B     641
# 88M     308
# 92A     275
# 91B     224
# 68W     207
#        ...
# 88D       1
# 270A      1
# 356H      1
# 35Q       1
# 91l       1
# Name: primarymos, Length: 281, dtype: int64

# %%
#There are letters and numbers that I can't understand for this feature. 
#Therefore, this column should also be dropped.

# %%
df.drop("primarymos", axis = 1, inplace = True)

# %%
df.select_dtypes("object")
# Out:
#       gender subjectsbirthlocation   dodrace writingpreference
# 0     Female               Germany     Black        Right hand
# 1     Female            California  Hispanic        Right hand
# 2     Female                 Texas     White        Right hand
# 3     Female  District of Columbia     Black        Right hand
# 4     Female                 Texas     White        Right hand
# ...      ...                   ...       ...               ...
# 6063    Male              Colorado     White        Right hand
# 6064    Male              Oklahoma     White        Right hand
# 6065    Male              Oklahoma     White        Right hand
# 6066    Male              Oklahoma     White        Right hand
# 6067    Male              Oklahoma     White        Right hand
#
# [5769 rows x 4 columns]

# %%
df.shape
# Out:
# (5769, 101)

# %% [markdown]
# ## Height (in)

# %% [markdown]
# Height in Inches; self-reported, comparable to measured “stature”

# %%
df.heightin.value_counts(dropna = False)
# Out:
# 69    605
# 70    551
# 71    537
# 66    522
# 68    511
# 67    485
# 72    468
# 64    368
# 65    299
# 73    283
# 63    249
# 74    232
# 62    208
# 75    114
# 61     89
# 60     72
# 76     68
# 77     36
# 59     30
# 78     15
# 80      7
# 57      5
# 79      5
# 58      4
# 81      2
# 56      1
# 87      1
# 86      1
# 94      1
# Name: heightin, dtype: int64

# %%
plt.figure(figsize=(10,6))

plt.subplot(211)
sns.boxplot(df.heightin)

plt.subplot(212)
sns.stripplot(df.heightin);

# %%
## We need to convert from inches to centimeters. 
#1 cm = 0.3937 in

# %%
df["heightcm"] = round(df["heightin"] / 0.3937)

# %%
df.heightcm.value_counts()
# Out:
# 175.0    605
# 178.0    551
# 180.0    537
# 168.0    522
# 173.0    511
# 170.0    485
# 183.0    468
# 163.0    368
# 165.0    299
# 185.0    283
# 160.0    249
# 188.0    232
# 157.0    208
# 191.0    114
# 155.0     89
# 152.0     72
# 193.0     68
# 196.0     36
# 150.0     30
# 198.0     15
# 203.0      7
# 145.0      5
# 201.0      5
# 147.0      4
# 206.0      2
# 142.0      1
# 221.0      1
# 218.0      1
# 239.0      1
# Name: heightcm, dtype: int64

# %%
plt.figure(figsize=(10,6))

plt.subplot(211)
sns.boxplot(df.heightcm)

plt.subplot(212)
sns.stripplot(df.heightcm);

# %%
df.drop("heightin", axis = 1, inplace = True)

# %%
df.drop("heightcm", axis = 1, inplace = True)

# %% [markdown]
# ## Weight (lbs)

# %% [markdown]
# Weight in Pounds; self-reported, comparable to measured “weightkg”

# %%
df.weightlbs.value_counts()
# Out:
# 170    224
# 180    219
# 150    216
# 175    204
# 160    203
#       ...
# 293      1
# 252      1
# 283      1
# 0        1
# 290      1
# Name: weightlbs, Length: 188, dtype: int64

# %%
## We need to convert from pounds to kilograms. 
#1 pound = 0.45359237 kg

# %%
df["weightkgs"] = round(df["weightlbs"] * 0.45359237)

# %%
df["weightkgs"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       64.0
# 1       54.0
# 2       67.0
# 3       79.0
# 4       88.0
#         ...
# 6063    73.0
# 6064    88.0
# 6065    84.0
# 6066    75.0
# 6067    99.0
# Name: weightkgs, Length: 5769, dtype: float64>

# %%
plt.figure(figsize=(10,6))

plt.subplot(211)
sns.boxplot(df.weightkgs)

plt.subplot(212)
sns.stripplot(df.weightkgs);

# %%
# I don't think a person's weight is an important value in estimating race. So we drop this column

# %%
df.drop("weightlbs", axis = 1, inplace = True)

# %%
df.drop("weightkgs", axis = 1, inplace = True)

# %% [markdown]
# ## Writing Preference

# %% [markdown]
# Writing Preference; “Right hand”, “Left hand”, or “Either hand (No preference)”

# %%
df.writingpreference.value_counts()
# Out:
# Right hand                     5088
# Left hand                       622
# Either hand (No preference)      59
# Name: writingpreference, dtype: int64

# %%
df.groupby(["writingpreference"])["dodrace"].value_counts(normalize=True)
# Out:
# writingpreference            dodrace
# Either hand (No preference)  White       0.728814
#                              Black       0.220339
#                              Hispanic    0.050847
# Left hand                    White       0.678457
#                              Black       0.241158
#                              Hispanic    0.080386
# Right hand                   White       0.653892
#                              Black       0.223074
#                              Hispanic    0.123035
# Name: dodrace, dtype: float64

# %%
grouped_df = df.groupby(["writingpreference"])["dodrace"].value_counts(normalize=True).reset_index(name="percentage")
ax = sns.barplot(x="writingpreference", y="percentage", hue="dodrace", data=grouped_df)
for p in ax.containers:
    ax.bar_label(p, label_type="edge", fontsize=8)
plt.show()

# %% [markdown]
# ## Subject Numeric Race

# %% [markdown]
# Subject Numeric Race; a single or multi-digit code indicating a subject’s self-reported race or races (verified through interview). Where 1 = White, 2 = Black, 3 = Hispanic, 4 = Asian, 5 = Native American, 6 = Pacific Islander, 8 = Other

# %%
df.subjectnumericrace.value_counts()
# Out:
# 1        3559
# 2        1025
# 3         541
# 31        159
# 8         106
# 51        102
# 21         60
# 23         34
# 28         26
# 251        20
# 41         19
# 18         16
# 61         15
# 25         13
# 38          9
# 351         9
# 42          6
# 62          6
# 231         6
# 35          5
# 235         4
# 63          3
# 43          3
# 218         3
# 431         2
# 423         2
# 2518        2
# 2351        2
# 451         1
# 4           1
# 238         1
# 358         1
# 318         1
# 651         1
# 425         1
# 42351       1
# 631         1
# 6           1
# 428         1
# 4251        1
# Name: subjectnumericrace, dtype: int64

# %%
#Although it is stated in the information note that the values vary from 1 to 8, 
#there are very different values in the data set. Therefore, this column needs to be dropped as well.

# %%
df.drop("subjectnumericrace", axis = 1, inplace = True)

# %% [markdown]
# ## Age

# %% [markdown]
# Participant’s age in years

# %%
df.age.value_counts()
# Out:
# 21    365
# 22    353
# 23    337
# 24    318
# 20    302
# 26    298
# 25    297
# 27    263
# 28    256
# 19    240
# 31    225
# 29    211
# 30    205
# 32    151
# 33    147
# 41    140
# 40    130
# 42    130
# 38    127
# 37    122
# 39    120
# 35    119
# 36    108
# 18    105
# 34    105
# 44     93
# 43     80
# 45     75
# 46     56
# 47     55
# 48     49
# 49     37
# 50     37
# 51     31
# 53     22
# 52     17
# 56     12
# 54     12
# 55      9
# 58      5
# 57      4
# 17      1
# Name: age, dtype: int64

# %%
df.age.unique()
# Out:
# array([26, 21, 23, 22, 45, 44, 24, 37, 33, 36, 40, 30, 19, 34, 31, 29, 28,
#        42, 25, 43, 20, 27, 41, 35, 38, 18, 32, 46, 39, 50, 47, 48, 52, 49,
#        51, 53, 56, 54, 55, 58, 17, 57], dtype=int64)

# %%
df.groupby(["age"])["dodrace"].value_counts()
# Out:
# age  dodrace
# 17   Black         1
# 18   White        69
#      Black        21
#      Hispanic     15
# 19   White       159
#                 ...
# 56   Hispanic      1
# 57   Black         2
#      White         2
# 58   White         4
#      Black         1
# Name: dodrace, Length: 121, dtype: int64

# %%
plt.figure(figsize=(10,6))

plt.subplot(211)
sns.boxplot(df.age)

plt.subplot(212)
sns.stripplot(df.age);

# %% [markdown]
# ## Gender

# %%
df.gender.value_counts()
# Out:
# Male      3899
# Female    1870
# Name: gender, dtype: int64

# %%
df.groupby(["gender"])["dodrace"].value_counts(normalize=True)
# Out:
# gender  dodrace
# Female  White       0.521390
#         Black       0.350802
#         Hispanic    0.127807
# Male    White       0.722493
#         Black       0.164658
#         Hispanic    0.112849
# Name: dodrace, dtype: float64

# %%
fig, ax = plt.subplots()
ax.pie(df.groupby(["gender"])["dodrace"].value_counts(normalize=True), labels=df.groupby(["gender"])["dodrace"].value_counts(normalize=True).index, autopct='%1.1f%%')
plt.show()

# %%
grouped_df = df.groupby(["gender"])["dodrace"].value_counts(normalize=True).reset_index(name="percentage")
ax = sns.barplot(x="gender", y="percentage", hue="dodrace", data=grouped_df)
for p in ax.containers:
    ax.bar_label(p, label_type="edge", fontsize=8)
plt.show()

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5769 entries, 0 to 6067
# Data columns (total 98 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   abdominalextensiondepthsitting  5769 non-null   int64
#  1   acromialheight                  5769 non-null   int64
#  2   acromionradialelength           5769 non-null   int64
#  3   anklecircumference              5769 non-null   int64
#  4   axillaheight                    5769 non-null   int64
#  5   balloffootcircumference         5769 non-null   int64
#  6   balloffootlength                5769 non-null   int64
#  7   biacromialbreadth               5769 non-null   int64
#  8   bicepscircumferenceflexed       5769 non-null   int64
#  9   bicristalbreadth                5769 non-null   int64
#  10  bideltoidbreadth                5769 non-null   int64
#  11  bimalleolarbreadth              5769 non-null   int64
#  12  bitragionchinarc                5769 non-null   int64
#  13  bitragionsubmandibulararc       5769 non-null   int64
#  14  bizygomaticbreadth              5769 non-null   int64
#  15  buttockcircumference            5769 non-null   int64
#  16  buttockdepth                    5769 non-null   int64
#  17  buttockheight                   5769 non-null   int64
#  18  buttockkneelength               5769 non-null   int64
#  19  buttockpopliteallength          5769 non-null   int64
#  20  calfcircumference               5769 non-null   int64
#  21  cervicaleheight                 5769 non-null   int64
#  22  chestbreadth                    5769 non-null   int64
#  23  chestcircumference              5769 non-null   int64
#  24  chestdepth                      5769 non-null   int64
#  25  chestheight                     5769 non-null   int64
#  26  crotchheight                    5769 non-null   int64
#  27  crotchlengthomphalion           5769 non-null   int64
#  28  crotchlengthposterioromphalion  5769 non-null   int64
#  29  earbreadth                      5769 non-null   int64
#  30  earlength                       5769 non-null   int64
#  31  earprotrusion                   5769 non-null   int64
#  32  elbowrestheight                 5769 non-null   int64
#  33  eyeheightsitting                5769 non-null   int64
#  34  footbreadthhorizontal           5769 non-null   int64
#  35  footlength                      5769 non-null   int64
#  36  forearmcenterofgriplength       5769 non-null   int64
#  37  forearmcircumferenceflexed      5769 non-null   int64
#  38  forearmforearmbreadth           5769 non-null   int64
#  39  forearmhandlength               5769 non-null   int64
#  40  functionalleglength             5769 non-null   int64
#  41  handbreadth                     5769 non-null   int64
#  42  handcircumference               5769 non-null   int64
#  43  handlength                      5769 non-null   int64
#  44  headbreadth                     5769 non-null   int64
#  45  headcircumference               5769 non-null   int64
#  46  headlength                      5769 non-null   int64
#  47  heelanklecircumference          5769 non-null   int64
#  48  heelbreadth                     5769 non-null   int64
#  49  hipbreadth                      5769 non-null   int64
#  50  hipbreadthsitting               5769 non-null   int64
#  51  iliocristaleheight              5769 non-null   int64
#  52  interpupillarybreadth           5769 non-null   int64
#  53  interscyei                      5769 non-null   int64
#  54  interscyeii                     5769 non-null   int64
#  55  kneeheightmidpatella            5769 non-null   int64
#  56  kneeheightsitting               5769 non-null   int64
#  57  lateralfemoralepicondyleheight  5769 non-null   int64
#  58  lateralmalleolusheight          5769 non-null   int64
#  59  lowerthighcircumference         5769 non-null   int64
#  60  mentonsellionlength             5769 non-null   int64
#  61  neckcircumference               5769 non-null   int64
#  62  neckcircumferencebase           5769 non-null   int64
#  63  overheadfingertipreachsitting   5769 non-null   int64
#  64  palmlength                      5769 non-null   int64
#  65  poplitealheight                 5769 non-null   int64
#  66  radialestylionlength            5769 non-null   int64
#  67  shouldercircumference           5769 non-null   int64
#  68  shoulderelbowlength             5769 non-null   int64
#  69  shoulderlength                  5769 non-null   int64
#  70  sittingheight                   5769 non-null   int64
#  71  sleevelengthspinewrist          5769 non-null   int64
#  72  sleeveoutseam                   5769 non-null   int64
#  73  span                            5769 non-null   int64
#  74  stature                         5769 non-null   int64
#  75  suprasternaleheight             5769 non-null   int64
#  76  tenthribheight                  5769 non-null   int64
#  77  thighcircumference              5769 non-null   int64
#  78  thighclearance                  5769 non-null   int64
#  79  thumbtipreach                   5769 non-null   int64
#  80  tibialheight                    5769 non-null   int64
#  81  tragiontopofhead                5769 non-null   int64
#  82  trochanterionheight             5769 non-null   int64
#  83  verticaltrunkcircumferenceusa   5769 non-null   int64
#  84  waistbacklength                 5769 non-null   int64
#  85  waistbreadth                    5769 non-null   int64
#  86  waistcircumference              5769 non-null   int64
#  87  waistdepth                      5769 non-null   int64
#  88  waistfrontlengthsitting         5769 non-null   int64
#  89  waistheightomphalion            5769 non-null   int64
#  90  weightkg                        5769 non-null   int64
#  91  wristcircumference              5769 non-null   int64
#  92  wristheight                     5769 non-null   int64
#  93  gender                          5769 non-null   object
#  94  subjectsbirthlocation           5769 non-null   object
#  95  dodrace                         5769 non-null   object
#  96  age                             5769 non-null   int64
#  97  writingpreference               5769 non-null   object
# dtypes: int64(94), object(4)
# memory usage: 4.5+ MB

# %%
plt.figure(figsize=(16,16))
sns.heatmap(df.corr(), vmin=-1, vmax=1, cmap = "magma");

# %% [markdown]
# ## Multicollinarity

# %%
df_numeric = df.select_dtypes("number")
df_numeric
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                                231            1282                    301
# 1                                194            1379                    320
# 2                                183            1369                    329
# 3                                261            1356                    306
# 4                                309            1303                    308
# ...                              ...             ...                    ...
# 6063                             235            1353                    312
# 6064                             247            1473                    336
# 6065                             264            1394                    313
# 6066                             203            1417                    327
# 6067                             327            1523                    358
#
#       anklecircumference  axillaheight  balloffootcircumference  \
# 0                    204          1180                      222
# 1                    207          1292                      225
# 2                    233          1271                      237
# 3                    214          1250                      240
# 4                    214          1210                      217
# ...                  ...           ...                      ...
# 6063                 216          1263                      228
# 6064                 234          1346                      253
# 6065                 227          1280                      245
# 6066                 223          1314                      250
# 6067                 226          1408                      269
#
#       balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0                  177                373                        315
# 1                  178                372                        272
# 2                  196                397                        300
# 3                  188                384                        364
# 4                  182                378                        320
# ...                ...                ...                        ...
# 6063               193                384                        318
# 6064               196                428                        374
# 6065               193                407                        367
# 6066               196                419                        365
# 6067               225                442                        379
#
#       bicristalbreadth  ...  waistbacklength  waistbreadth  \
# 0                  263  ...              406           295
# 1                  250  ...              422           254
# 2                  276  ...              419           269
# 3                  276  ...              451           302
# 4                  336  ...              452           405
# ...                ...  ...              ...           ...
# 6063               241  ...              442           279
# 6064               284  ...              475           351
# 6065               271  ...              483           333
# 6066               271  ...              430           293
# 6067               275  ...              511           354
#
#       waistcircumference  waistdepth  waistfrontlengthsitting  \
# 0                    850         217                      345
# 1                    708         168                      329
# 2                    727         159                      367
# 3                    923         235                      371
# 4                   1163         300                      380
# ...                  ...         ...                      ...
# 6063                 816         210                      347
# 6064                 978         235                      385
# 6065                 991         258                      353
# 6066                 783         192                      350
# 6067                1080         294                      389
#
#       waistheightomphalion  weightkg  wristcircumference  wristheight  age
# 0                      942       657                 152          756   26
# 1                     1032       534                 155          815   21
# 2                     1035       663                 162          799   23
# 3                      999       782                 173          818   22
# 4                      911       886                 152          762   45
# ...                    ...       ...                 ...          ...  ...
# 6063                  1016       675                 163          778   22
# 6064                  1082       896                 178          873   22
# 6065                  1011       832                 178          822   23
# 6066                  1062       731                 172          837   22
# 6067                  1119       985                 182          894   38
#
# [5769 rows x 94 columns]

# %%
from termcolor import cprint

def multicolinearity_control(df):                    
    df_temp = df.corr()
    count = 'Done'
    feature =[]
    collinear= []
    for col in df_temp.columns:
        for i in df_temp.index:
            if abs(df_temp[col][i] > .6 and df_temp[col][i] < 1):
                    feature.append(col)
                    collinear.append(i)
                    cprint(f"Multicolinearity alert in between --> {col} - {i} --> {round(df_temp[col][i], 6)}", "red", attrs=["bold"])
    else:
#         cprint(f"There is NO multicollinearity problem.", "blue", attrs=["bold"])
        pass

# %%
multicolinearity_control(df_numeric)
# Out:
# Multicolinearity alert in between --> abdominalextensiondepthsitting - bicepscircumferenceflexed --> 0.691126
# Multicolinearity alert in between --> abdominalextensiondepthsitting - bideltoidbreadth --> 0.724344
# Multicolinearity alert in between --> abdominalextensiondepthsitting - bitragionsubmandibulararc --> 0.626294
# Multicolinearity alert in between --> abdominalextensiondepthsitting - buttockcircumference --> 0.739481
# Multicolinearity alert in between --> abdominalextensiondepthsitting - buttockdepth --> 0.840828
# Multicolinearity alert in between --> abdominalextensiondepthsitting - calfcircumference --> 0.658512
# Multicolinearity alert in between --> abdominalextensiondepthsitting - chestbreadth --> 0.627868
# Multicolinearity alert in between --> abdominalextensiondepthsitting - chestcircumference --> 0.82583
# Multicolinearity alert in between --> abdominalextensiondepthsitting - chestdepth --> 0.778442
# Multicolinearity alert in between --> abdominalextensiondepthsitting - forearmcircumferenceflexed --> 0.628312
# Multicolinearity alert in between --> abdominalextensiondepthsitting - forearmforearmbreadth --> 0.728934
# Multicolinearity alert in between --> abdominalextensiondepthsitting - lowerthighcircumference --> 0.67441
# Multicolinearity alert in between --> abdominalextensiondepthsitting - neckcircumference --> 0.656883
# Multicolinearity alert in between --> abdominalextensiondepthsitting - neckcircumferencebase --> 0.627212
# Multicolinearity alert in between --> abdominalextensiondepthsitting - shouldercircumference --> 0.637863
# Multicolinearity alert in between --> abdominalextensiondepthsitting - thighcircumference --> 0.730017
# Multicolinearity alert in between --> abdominalextensiondepthsitting - thighclearance --> 0.724702
# Multicolinearity alert in between --> abdominalextensiondepthsitting - verticaltrunkcircumferenceusa --> 0.728538
# Multicolinearity alert in between --> abdominalextensiondepthsitting - waistbreadth --> 0.858962
# Multicolinearity alert in between --> abdominalextensiondepthsitting - waistcircumference --> 0.939645
# Multicolinearity alert in between --> abdominalextensiondepthsitting - waistdepth --> 0.958716
# Multicolinearity alert in between --> abdominalextensiondepthsitting - weightkg --> 0.825198
# Multicolinearity alert in between --> acromialheight - acromionradialelength --> 0.868267
# Multicolinearity alert in between --> acromialheight - axillaheight --> 0.987115
# Multicolinearity alert in between --> acromialheight - balloffootcircumference --> 0.693952
# Multicolinearity alert in between --> acromialheight - balloffootlength --> 0.797793
# Multicolinearity alert in between --> acromialheight - biacromialbreadth --> 0.733288
# Multicolinearity alert in between --> acromialheight - bideltoidbreadth --> 0.62849
# Multicolinearity alert in between --> acromialheight - bimalleolarbreadth --> 0.705043
# Multicolinearity alert in between --> acromialheight - buttockheight --> 0.866969
# Multicolinearity alert in between --> acromialheight - buttockkneelength --> 0.811402
# Multicolinearity alert in between --> acromialheight - buttockpopliteallength --> 0.74673
# Multicolinearity alert in between --> acromialheight - cervicaleheight --> 0.983955
# Multicolinearity alert in between --> acromialheight - chestheight --> 0.9593
# Multicolinearity alert in between --> acromialheight - crotchheight --> 0.898981
# Multicolinearity alert in between --> acromialheight - eyeheightsitting --> 0.813617
# Multicolinearity alert in between --> acromialheight - footbreadthhorizontal --> 0.671984
# Multicolinearity alert in between --> acromialheight - footlength --> 0.826817
# Multicolinearity alert in between --> acromialheight - forearmcenterofgriplength --> 0.846525
# Multicolinearity alert in between --> acromialheight - forearmcircumferenceflexed --> 0.635454
# Multicolinearity alert in between --> acromialheight - forearmhandlength --> 0.862543
# Multicolinearity alert in between --> acromialheight - functionalleglength --> 0.893985
# Multicolinearity alert in between --> acromialheight - handbreadth --> 0.708512
# Multicolinearity alert in between --> acromialheight - handcircumference --> 0.717048
# Multicolinearity alert in between --> acromialheight - handlength --> 0.752909
# Multicolinearity alert in between --> acromialheight - heelanklecircumference --> 0.79738
# Multicolinearity alert in between --> acromialheight - iliocristaleheight --> 0.932232
# Multicolinearity alert in between --> acromialheight - kneeheightmidpatella --> 0.895907
# Multicolinearity alert in between --> acromialheight - kneeheightsitting --> 0.931762
# Multicolinearity alert in between --> acromialheight - lateralfemoralepicondyleheight --> 0.856497
# Multicolinearity alert in between --> acromialheight - lateralmalleolusheight --> 0.677825
# Multicolinearity alert in between --> acromialheight - neckcircumference --> 0.627926
# Multicolinearity alert in between --> acromialheight - neckcircumferencebase --> 0.651816
# Multicolinearity alert in between --> acromialheight - overheadfingertipreachsitting --> 0.867356
# Multicolinearity alert in between --> acromialheight - palmlength --> 0.709205
# Multicolinearity alert in between --> acromialheight - poplitealheight --> 0.8934
# Multicolinearity alert in between --> acromialheight - radialestylionlength --> 0.821761
# Multicolinearity alert in between --> acromialheight - shouldercircumference --> 0.689824
# Multicolinearity alert in between --> acromialheight - shoulderelbowlength --> 0.889043
# Multicolinearity alert in between --> acromialheight - sittingheight --> 0.821495
# Multicolinearity alert in between --> acromialheight - sleevelengthspinewrist --> 0.872367
# Multicolinearity alert in between --> acromialheight - sleeveoutseam --> 0.879767
# Multicolinearity alert in between --> acromialheight - span --> 0.883966
# Multicolinearity alert in between --> acromialheight - stature --> 0.979925
# Multicolinearity alert in between --> acromialheight - suprasternaleheight --> 0.984711
# Multicolinearity alert in between --> acromialheight - tenthribheight --> 0.945019
# Multicolinearity alert in between --> acromialheight - thumbtipreach --> 0.80368
# Multicolinearity alert in between --> acromialheight - tibialheight --> 0.890896
# Multicolinearity alert in between --> acromialheight - trochanterionheight --> 0.883719
# Multicolinearity alert in between --> acromialheight - verticaltrunkcircumferenceusa --> 0.733662
# Multicolinearity alert in between --> acromialheight - waistbacklength --> 0.727869
# Multicolinearity alert in between --> acromialheight - waistfrontlengthsitting --> 0.60702
# Multicolinearity alert in between --> acromialheight - waistheightomphalion --> 0.930954
# Multicolinearity alert in between --> acromialheight - weightkg --> 0.677768
# Multicolinearity alert in between --> acromialheight - wristcircumference --> 0.733564
# Multicolinearity alert in between --> acromialheight - wristheight --> 0.921268
# Multicolinearity alert in between --> acromionradialelength - acromialheight --> 0.868267
# Multicolinearity alert in between --> acromionradialelength - axillaheight --> 0.857391
# Multicolinearity alert in between --> acromionradialelength - balloffootcircumference --> 0.604208
# Multicolinearity alert in between --> acromionradialelength - balloffootlength --> 0.725966
# Multicolinearity alert in between --> acromionradialelength - biacromialbreadth --> 0.667377
# Multicolinearity alert in between --> acromionradialelength - bimalleolarbreadth --> 0.61483
# Multicolinearity alert in between --> acromionradialelength - buttockheight --> 0.814136
# Multicolinearity alert in between --> acromionradialelength - buttockkneelength --> 0.775389
# Multicolinearity alert in between --> acromionradialelength - buttockpopliteallength --> 0.735224
# Multicolinearity alert in between --> acromionradialelength - cervicaleheight --> 0.865821
# Multicolinearity alert in between --> acromionradialelength - chestheight --> 0.841836
# Multicolinearity alert in between --> acromionradialelength - crotchheight --> 0.850474
# Multicolinearity alert in between --> acromionradialelength - eyeheightsitting --> 0.639168
# Multicolinearity alert in between --> acromionradialelength - footlength --> 0.748856
# Multicolinearity alert in between --> acromionradialelength - forearmcenterofgriplength --> 0.818087
# Multicolinearity alert in between --> acromionradialelength - forearmhandlength --> 0.836295
# Multicolinearity alert in between --> acromionradialelength - functionalleglength --> 0.820203
# Multicolinearity alert in between --> acromionradialelength - handbreadth --> 0.623868
# Multicolinearity alert in between --> acromionradialelength - handcircumference --> 0.632046
# Multicolinearity alert in between --> acromionradialelength - handlength --> 0.719796
# Multicolinearity alert in between --> acromionradialelength - heelanklecircumference --> 0.709314
# Multicolinearity alert in between --> acromionradialelength - iliocristaleheight --> 0.858546
# Multicolinearity alert in between --> acromionradialelength - kneeheightmidpatella --> 0.831054
# Multicolinearity alert in between --> acromionradialelength - kneeheightsitting --> 0.861147
# Multicolinearity alert in between --> acromionradialelength - lateralfemoralepicondyleheight --> 0.812201
# Multicolinearity alert in between --> acromionradialelength - overheadfingertipreachsitting --> 0.791049
# Multicolinearity alert in between --> acromionradialelength - palmlength --> 0.665143
# Multicolinearity alert in between --> acromionradialelength - poplitealheight --> 0.828767
# Multicolinearity alert in between --> acromionradialelength - radialestylionlength --> 0.80001
# Multicolinearity alert in between --> acromionradialelength - shouldercircumference --> 0.621075
# Multicolinearity alert in between --> acromionradialelength - shoulderelbowlength --> 0.9675
# Multicolinearity alert in between --> acromionradialelength - sittingheight --> 0.646636
# Multicolinearity alert in between --> acromionradialelength - sleevelengthspinewrist --> 0.871455
# Multicolinearity alert in between --> acromionradialelength - sleeveoutseam --> 0.939807
# Multicolinearity alert in between --> acromionradialelength - span --> 0.894015
# Multicolinearity alert in between --> acromionradialelength - stature --> 0.855635
# Multicolinearity alert in between --> acromionradialelength - suprasternaleheight --> 0.862129
# Multicolinearity alert in between --> acromionradialelength - tenthribheight --> 0.849321
# Multicolinearity alert in between --> acromionradialelength - thumbtipreach --> 0.800831
# Multicolinearity alert in between --> acromionradialelength - tibialheight --> 0.825015
# Multicolinearity alert in between --> acromionradialelength - trochanterionheight --> 0.832104
# Multicolinearity alert in between --> acromionradialelength - waistbacklength --> 0.609591
# Multicolinearity alert in between --> acromionradialelength - waistheightomphalion --> 0.845864
# Multicolinearity alert in between --> acromionradialelength - wristcircumference --> 0.642518
# Multicolinearity alert in between --> acromionradialelength - wristheight --> 0.67714
# Multicolinearity alert in between --> anklecircumference - balloffootcircumference --> 0.70955
# Multicolinearity alert in between --> anklecircumference - bicepscircumferenceflexed --> 0.637641
# Multicolinearity alert in between --> anklecircumference - bideltoidbreadth --> 0.641173
# Multicolinearity alert in between --> anklecircumference - bimalleolarbreadth --> 0.692289
# Multicolinearity alert in between --> anklecircumference - calfcircumference --> 0.817155
# Multicolinearity alert in between --> anklecircumference - chestcircumference --> 0.612861
# Multicolinearity alert in between --> anklecircumference - footbreadthhorizontal --> 0.651467
# Multicolinearity alert in between --> anklecircumference - forearmcircumferenceflexed --> 0.662702
# Multicolinearity alert in between --> anklecircumference - forearmforearmbreadth --> 0.612152
# Multicolinearity alert in between --> anklecircumference - handcircumference --> 0.607766
# Multicolinearity alert in between --> anklecircumference - heelanklecircumference --> 0.729474
# Multicolinearity alert in between --> anklecircumference - lowerthighcircumference --> 0.697103
# Multicolinearity alert in between --> anklecircumference - shouldercircumference --> 0.629105
# Multicolinearity alert in between --> anklecircumference - thighclearance --> 0.648125
# Multicolinearity alert in between --> anklecircumference - verticaltrunkcircumferenceusa --> 0.665049
# Multicolinearity alert in between --> anklecircumference - weightkg --> 0.741326
# Multicolinearity alert in between --> anklecircumference - wristcircumference --> 0.697485
# Multicolinearity alert in between --> axillaheight - acromialheight --> 0.987115
# Multicolinearity alert in between --> axillaheight - acromionradialelength --> 0.857391
# Multicolinearity alert in between --> axillaheight - balloffootcircumference --> 0.657023
# Multicolinearity alert in between --> axillaheight - balloffootlength --> 0.785011
# Multicolinearity alert in between --> axillaheight - biacromialbreadth --> 0.705028
# Multicolinearity alert in between --> axillaheight - bimalleolarbreadth --> 0.675799
# Multicolinearity alert in between --> axillaheight - buttockheight --> 0.883016
# Multicolinearity alert in between --> axillaheight - buttockkneelength --> 0.8086
# Multicolinearity alert in between --> axillaheight - buttockpopliteallength --> 0.759231
# Multicolinearity alert in between --> axillaheight - cervicaleheight --> 0.976609
# Multicolinearity alert in between --> axillaheight - chestheight --> 0.956096
# Multicolinearity alert in between --> axillaheight - crotchheight --> 0.915316
# Multicolinearity alert in between --> axillaheight - eyeheightsitting --> 0.792819
# Multicolinearity alert in between --> axillaheight - footbreadthhorizontal --> 0.638811
# Multicolinearity alert in between --> axillaheight - footlength --> 0.815581
# Multicolinearity alert in between --> axillaheight - forearmcenterofgriplength --> 0.846478
# Multicolinearity alert in between --> axillaheight - forearmhandlength --> 0.865252
# Multicolinearity alert in between --> axillaheight - functionalleglength --> 0.887249
# Multicolinearity alert in between --> axillaheight - handbreadth --> 0.669378
# Multicolinearity alert in between --> axillaheight - handcircumference --> 0.67449
# Multicolinearity alert in between --> axillaheight - handlength --> 0.755064
# Multicolinearity alert in between --> axillaheight - heelanklecircumference --> 0.767181
# Multicolinearity alert in between --> axillaheight - iliocristaleheight --> 0.946228
# Multicolinearity alert in between --> axillaheight - kneeheightmidpatella --> 0.903028
# Multicolinearity alert in between --> axillaheight - kneeheightsitting --> 0.933482
# Multicolinearity alert in between --> axillaheight - lateralfemoralepicondyleheight --> 0.872441
# Multicolinearity alert in between --> axillaheight - lateralmalleolusheight --> 0.648097
# Multicolinearity alert in between --> axillaheight - overheadfingertipreachsitting --> 0.860704
# Multicolinearity alert in between --> axillaheight - palmlength --> 0.703817
# Multicolinearity alert in between --> axillaheight - poplitealheight --> 0.905677
# Multicolinearity alert in between --> axillaheight - radialestylionlength --> 0.826284
# Multicolinearity alert in between --> axillaheight - shouldercircumference --> 0.636585
# Multicolinearity alert in between --> axillaheight - shoulderelbowlength --> 0.879262
# Multicolinearity alert in between --> axillaheight - sittingheight --> 0.800178
# Multicolinearity alert in between --> axillaheight - sleevelengthspinewrist --> 0.849738
# Multicolinearity alert in between --> axillaheight - sleeveoutseam --> 0.875045
# Multicolinearity alert in between --> axillaheight - span --> 0.883976
# Multicolinearity alert in between --> axillaheight - stature --> 0.975436
# Multicolinearity alert in between --> axillaheight - suprasternaleheight --> 0.980594
# Multicolinearity alert in between --> axillaheight - tenthribheight --> 0.954317
# Multicolinearity alert in between --> axillaheight - thumbtipreach --> 0.79588
# Multicolinearity alert in between --> axillaheight - tibialheight --> 0.904542
# Multicolinearity alert in between --> axillaheight - trochanterionheight --> 0.899598
# Multicolinearity alert in between --> axillaheight - verticaltrunkcircumferenceusa --> 0.675137
# Multicolinearity alert in between --> axillaheight - waistbacklength --> 0.679879
# Multicolinearity alert in between --> axillaheight - waistheightomphalion --> 0.946468
# Multicolinearity alert in between --> axillaheight - weightkg --> 0.613565
# Multicolinearity alert in between --> axillaheight - wristcircumference --> 0.685336
# Multicolinearity alert in between --> axillaheight - wristheight --> 0.903063
# Multicolinearity alert in between --> balloffootcircumference - acromialheight --> 0.693952
# Multicolinearity alert in between --> balloffootcircumference - acromionradialelength --> 0.604208
# Multicolinearity alert in between --> balloffootcircumference - anklecircumference --> 0.70955
# Multicolinearity alert in between --> balloffootcircumference - axillaheight --> 0.657023
# Multicolinearity alert in between --> balloffootcircumference - balloffootlength --> 0.744905
# Multicolinearity alert in between --> balloffootcircumference - biacromialbreadth --> 0.735577
# Multicolinearity alert in between --> balloffootcircumference - bicepscircumferenceflexed --> 0.662673
# Multicolinearity alert in between --> balloffootcircumference - bideltoidbreadth --> 0.7156
# Multicolinearity alert in between --> balloffootcircumference - bimalleolarbreadth --> 0.799207
# Multicolinearity alert in between --> balloffootcircumference - bitragionchinarc --> 0.657071
# Multicolinearity alert in between --> balloffootcircumference - bitragionsubmandibulararc --> 0.652441
# Multicolinearity alert in between --> balloffootcircumference - bizygomaticbreadth --> 0.615447
# Multicolinearity alert in between --> balloffootcircumference - calfcircumference --> 0.619158
# Multicolinearity alert in between --> balloffootcircumference - cervicaleheight --> 0.712763
# Multicolinearity alert in between --> balloffootcircumference - chestcircumference --> 0.628574
# Multicolinearity alert in between --> balloffootcircumference - chestheight --> 0.701653
# Multicolinearity alert in between --> balloffootcircumference - eyeheightsitting --> 0.649383
# Multicolinearity alert in between --> balloffootcircumference - footbreadthhorizontal --> 0.922957
# Multicolinearity alert in between --> balloffootcircumference - footlength --> 0.778193
# Multicolinearity alert in between --> balloffootcircumference - forearmcenterofgriplength --> 0.674801
# Multicolinearity alert in between --> balloffootcircumference - forearmcircumferenceflexed --> 0.755403
# Multicolinearity alert in between --> balloffootcircumference - forearmforearmbreadth --> 0.667103
# Multicolinearity alert in between --> balloffootcircumference - forearmhandlength --> 0.689875
# Multicolinearity alert in between --> balloffootcircumference - functionalleglength --> 0.665806
# Multicolinearity alert in between --> balloffootcircumference - handbreadth --> 0.821448
# Multicolinearity alert in between --> balloffootcircumference - handcircumference --> 0.837594
# Multicolinearity alert in between --> balloffootcircumference - handlength --> 0.655917
# Multicolinearity alert in between --> balloffootcircumference - heelanklecircumference --> 0.862604
# Multicolinearity alert in between --> balloffootcircumference - heelbreadth --> 0.63264
# Multicolinearity alert in between --> balloffootcircumference - iliocristaleheight --> 0.607117
# Multicolinearity alert in between --> balloffootcircumference - interscyei --> 0.601936
# Multicolinearity alert in between --> balloffootcircumference - interscyeii --> 0.643601
# Multicolinearity alert in between --> balloffootcircumference - kneeheightmidpatella --> 0.621928
# Multicolinearity alert in between --> balloffootcircumference - kneeheightsitting --> 0.697842
# Multicolinearity alert in between --> balloffootcircumference - lateralmalleolusheight --> 0.644127
# Multicolinearity alert in between --> balloffootcircumference - neckcircumference --> 0.728229
# Multicolinearity alert in between --> balloffootcircumference - neckcircumferencebase --> 0.727908
# Multicolinearity alert in between --> balloffootcircumference - overheadfingertipreachsitting --> 0.683058
# Multicolinearity alert in between --> balloffootcircumference - palmlength --> 0.623517
# Multicolinearity alert in between --> balloffootcircumference - poplitealheight --> 0.615508
# Multicolinearity alert in between --> balloffootcircumference - radialestylionlength --> 0.628984
# Multicolinearity alert in between --> balloffootcircumference - shouldercircumference --> 0.763225
# Multicolinearity alert in between --> balloffootcircumference - shoulderelbowlength --> 0.637597
# Multicolinearity alert in between --> balloffootcircumference - sittingheight --> 0.657675
# Multicolinearity alert in between --> balloffootcircumference - sleevelengthspinewrist --> 0.748216
# Multicolinearity alert in between --> balloffootcircumference - sleeveoutseam --> 0.629807
# Multicolinearity alert in between --> balloffootcircumference - span --> 0.692939
# Multicolinearity alert in between --> balloffootcircumference - stature --> 0.710313
# Multicolinearity alert in between --> balloffootcircumference - suprasternaleheight --> 0.711629
# Multicolinearity alert in between --> balloffootcircumference - tenthribheight --> 0.616035
# Multicolinearity alert in between --> balloffootcircumference - thumbtipreach --> 0.640233
# Multicolinearity alert in between --> balloffootcircumference - verticaltrunkcircumferenceusa --> 0.677161
# Multicolinearity alert in between --> balloffootcircumference - waistbacklength --> 0.640714
# Multicolinearity alert in between --> balloffootcircumference - waistheightomphalion --> 0.618589
# Multicolinearity alert in between --> balloffootcircumference - weightkg --> 0.73092
# Multicolinearity alert in between --> balloffootcircumference - wristcircumference --> 0.827143
# Multicolinearity alert in between --> balloffootcircumference - wristheight --> 0.62962
# Multicolinearity alert in between --> balloffootlength - acromialheight --> 0.797793
# Multicolinearity alert in between --> balloffootlength - acromionradialelength --> 0.725966
# Multicolinearity alert in between --> balloffootlength - axillaheight --> 0.785011
# Multicolinearity alert in between --> balloffootlength - balloffootcircumference --> 0.744905
# Multicolinearity alert in between --> balloffootlength - biacromialbreadth --> 0.74019
# Multicolinearity alert in between --> balloffootlength - bideltoidbreadth --> 0.631668
# Multicolinearity alert in between --> balloffootlength - bimalleolarbreadth --> 0.768204
# Multicolinearity alert in between --> balloffootlength - bitragionchinarc --> 0.616681
# Multicolinearity alert in between --> balloffootlength - buttockheight --> 0.73438
# Multicolinearity alert in between --> balloffootlength - buttockkneelength --> 0.713997
# Multicolinearity alert in between --> balloffootlength - buttockpopliteallength --> 0.645987
# Multicolinearity alert in between --> balloffootlength - cervicaleheight --> 0.817553
# Multicolinearity alert in between --> balloffootlength - chestheight --> 0.81395
# Multicolinearity alert in between --> balloffootlength - crotchheight --> 0.776582
# Multicolinearity alert in between --> balloffootlength - eyeheightsitting --> 0.632633
# Multicolinearity alert in between --> balloffootlength - footbreadthhorizontal --> 0.733009
# Multicolinearity alert in between --> balloffootlength - footlength --> 0.959326
# Multicolinearity alert in between --> balloffootlength - forearmcenterofgriplength --> 0.806386
# Multicolinearity alert in between --> balloffootlength - forearmcircumferenceflexed --> 0.680779
# Multicolinearity alert in between --> balloffootlength - forearmhandlength --> 0.848221
# Multicolinearity alert in between --> balloffootlength - functionalleglength --> 0.767115
# Multicolinearity alert in between --> balloffootlength - handbreadth --> 0.739232
# Multicolinearity alert in between --> balloffootlength - handcircumference --> 0.747906
# Multicolinearity alert in between --> balloffootlength - handlength --> 0.788469
# Multicolinearity alert in between --> balloffootlength - heelanklecircumference --> 0.865269
# Multicolinearity alert in between --> balloffootlength - heelbreadth --> 0.622207
# Multicolinearity alert in between --> balloffootlength - iliocristaleheight --> 0.76793
# Multicolinearity alert in between --> balloffootlength - interscyeii --> 0.602488
# Multicolinearity alert in between --> balloffootlength - kneeheightmidpatella --> 0.782662
# Multicolinearity alert in between --> balloffootlength - kneeheightsitting --> 0.819298
# Multicolinearity alert in between --> balloffootlength - lateralfemoralepicondyleheight --> 0.729327
# Multicolinearity alert in between --> balloffootlength - neckcircumference --> 0.649874
# Multicolinearity alert in between --> balloffootlength - neckcircumferencebase --> 0.655121
# Multicolinearity alert in between --> balloffootlength - overheadfingertipreachsitting --> 0.718956
# Multicolinearity alert in between --> balloffootlength - palmlength --> 0.750548
# Multicolinearity alert in between --> balloffootlength - poplitealheight --> 0.783707
# Multicolinearity alert in between --> balloffootlength - radialestylionlength --> 0.786662
# Multicolinearity alert in between --> balloffootlength - shouldercircumference --> 0.709537
# Multicolinearity alert in between --> balloffootlength - shoulderelbowlength --> 0.748979
# Multicolinearity alert in between --> balloffootlength - sittingheight --> 0.64868
# Multicolinearity alert in between --> balloffootlength - sleevelengthspinewrist --> 0.8225
# Multicolinearity alert in between --> balloffootlength - sleeveoutseam --> 0.784623
# Multicolinearity alert in between --> balloffootlength - span --> 0.81837
# Multicolinearity alert in between --> balloffootlength - stature --> 0.810996
# Multicolinearity alert in between --> balloffootlength - suprasternaleheight --> 0.809877
# Multicolinearity alert in between --> balloffootlength - tenthribheight --> 0.777551
# Multicolinearity alert in between --> balloffootlength - thumbtipreach --> 0.752869
# Multicolinearity alert in between --> balloffootlength - tibialheight --> 0.73923
# Multicolinearity alert in between --> balloffootlength - trochanterionheight --> 0.738446
# Multicolinearity alert in between --> balloffootlength - waistbacklength --> 0.631696
# Multicolinearity alert in between --> balloffootlength - waistheightomphalion --> 0.77802
# Multicolinearity alert in between --> balloffootlength - weightkg --> 0.645382
# Multicolinearity alert in between --> balloffootlength - wristcircumference --> 0.74323
# Multicolinearity alert in between --> balloffootlength - wristheight --> 0.683307
# Multicolinearity alert in between --> biacromialbreadth - acromialheight --> 0.733288
# Multicolinearity alert in between --> biacromialbreadth - acromionradialelength --> 0.667377
# Multicolinearity alert in between --> biacromialbreadth - axillaheight --> 0.705028
# Multicolinearity alert in between --> biacromialbreadth - balloffootcircumference --> 0.735577
# Multicolinearity alert in between --> biacromialbreadth - balloffootlength --> 0.74019
# Multicolinearity alert in between --> biacromialbreadth - bicepscircumferenceflexed --> 0.663869
# Multicolinearity alert in between --> biacromialbreadth - bideltoidbreadth --> 0.825971
# Multicolinearity alert in between --> biacromialbreadth - bimalleolarbreadth --> 0.721064
# Multicolinearity alert in between --> biacromialbreadth - bitragionchinarc --> 0.669708
# Multicolinearity alert in between --> biacromialbreadth - bitragionsubmandibulararc --> 0.669106
# Multicolinearity alert in between --> biacromialbreadth - bizygomaticbreadth --> 0.634934
# Multicolinearity alert in between --> biacromialbreadth - buttockheight --> 0.606094
# Multicolinearity alert in between --> biacromialbreadth - cervicaleheight --> 0.780834
# Multicolinearity alert in between --> biacromialbreadth - chestbreadth --> 0.646817
# Multicolinearity alert in between --> biacromialbreadth - chestcircumference --> 0.641346
# Multicolinearity alert in between --> biacromialbreadth - chestheight --> 0.765231
# Multicolinearity alert in between --> biacromialbreadth - crotchheight --> 0.65338
# Multicolinearity alert in between --> biacromialbreadth - eyeheightsitting --> 0.696241
# Multicolinearity alert in between --> biacromialbreadth - footbreadthhorizontal --> 0.710003
# Multicolinearity alert in between --> biacromialbreadth - footlength --> 0.761809
# Multicolinearity alert in between --> biacromialbreadth - forearmcenterofgriplength --> 0.737728
# Multicolinearity alert in between --> biacromialbreadth - forearmcircumferenceflexed --> 0.764349
# Multicolinearity alert in between --> biacromialbreadth - forearmforearmbreadth --> 0.702459
# Multicolinearity alert in between --> biacromialbreadth - forearmhandlength --> 0.745695
# Multicolinearity alert in between --> biacromialbreadth - functionalleglength --> 0.710094
# Multicolinearity alert in between --> biacromialbreadth - handbreadth --> 0.768059
# Multicolinearity alert in between --> biacromialbreadth - handcircumference --> 0.789693
# Multicolinearity alert in between --> biacromialbreadth - handlength --> 0.652211
# Multicolinearity alert in between --> biacromialbreadth - heelanklecircumference --> 0.784705
# Multicolinearity alert in between --> biacromialbreadth - iliocristaleheight --> 0.663666
# Multicolinearity alert in between --> biacromialbreadth - interscyei --> 0.712148
# Multicolinearity alert in between --> biacromialbreadth - interscyeii --> 0.804802
# Multicolinearity alert in between --> biacromialbreadth - kneeheightmidpatella --> 0.673508
# Multicolinearity alert in between --> biacromialbreadth - kneeheightsitting --> 0.725769
# Multicolinearity alert in between --> biacromialbreadth - lateralmalleolusheight --> 0.627204
# Multicolinearity alert in between --> biacromialbreadth - neckcircumference --> 0.789767
# Multicolinearity alert in between --> biacromialbreadth - neckcircumferencebase --> 0.80337
# Multicolinearity alert in between --> biacromialbreadth - overheadfingertipreachsitting --> 0.767989
# Multicolinearity alert in between --> biacromialbreadth - palmlength --> 0.63509
# Multicolinearity alert in between --> biacromialbreadth - poplitealheight --> 0.692218
# Multicolinearity alert in between --> biacromialbreadth - radialestylionlength --> 0.711794
# Multicolinearity alert in between --> biacromialbreadth - shouldercircumference --> 0.900032
# Multicolinearity alert in between --> biacromialbreadth - shoulderelbowlength --> 0.71473
# Multicolinearity alert in between --> biacromialbreadth - shoulderlength --> 0.776611
# Multicolinearity alert in between --> biacromialbreadth - sittingheight --> 0.703886
# Multicolinearity alert in between --> biacromialbreadth - sleevelengthspinewrist --> 0.861473
# Multicolinearity alert in between --> biacromialbreadth - sleeveoutseam --> 0.710444
# Multicolinearity alert in between --> biacromialbreadth - span --> 0.804811
# Multicolinearity alert in between --> biacromialbreadth - stature --> 0.770284
# Multicolinearity alert in between --> biacromialbreadth - suprasternaleheight --> 0.762207
# Multicolinearity alert in between --> biacromialbreadth - tenthribheight --> 0.665017
# Multicolinearity alert in between --> biacromialbreadth - thumbtipreach --> 0.705933
# Multicolinearity alert in between --> biacromialbreadth - tibialheight --> 0.634041
# Multicolinearity alert in between --> biacromialbreadth - trochanterionheight --> 0.620755
# Multicolinearity alert in between --> biacromialbreadth - verticaltrunkcircumferenceusa --> 0.65576
# Multicolinearity alert in between --> biacromialbreadth - waistbacklength --> 0.685222
# Multicolinearity alert in between --> biacromialbreadth - waistheightomphalion --> 0.688401
# Multicolinearity alert in between --> biacromialbreadth - weightkg --> 0.703679
# Multicolinearity alert in between --> biacromialbreadth - wristcircumference --> 0.803051
# Multicolinearity alert in between --> biacromialbreadth - wristheight --> 0.621811
# Multicolinearity alert in between --> bicepscircumferenceflexed - abdominalextensiondepthsitting --> 0.691126
# Multicolinearity alert in between --> bicepscircumferenceflexed - anklecircumference --> 0.637641
# Multicolinearity alert in between --> bicepscircumferenceflexed - balloffootcircumference --> 0.662673
# Multicolinearity alert in between --> bicepscircumferenceflexed - biacromialbreadth --> 0.663869
# Multicolinearity alert in between --> bicepscircumferenceflexed - bideltoidbreadth --> 0.874071
# Multicolinearity alert in between --> bicepscircumferenceflexed - bitragionchinarc --> 0.676975
# Multicolinearity alert in between --> bicepscircumferenceflexed - bitragionsubmandibulararc --> 0.709026
# Multicolinearity alert in between --> bicepscircumferenceflexed - bizygomaticbreadth --> 0.641649
# Multicolinearity alert in between --> bicepscircumferenceflexed - buttockdepth --> 0.703188
# Multicolinearity alert in between --> bicepscircumferenceflexed - calfcircumference --> 0.72006
# Multicolinearity alert in between --> bicepscircumferenceflexed - chestbreadth --> 0.664048
# Multicolinearity alert in between --> bicepscircumferenceflexed - chestcircumference --> 0.840274
# Multicolinearity alert in between --> bicepscircumferenceflexed - chestdepth --> 0.655055
# Multicolinearity alert in between --> bicepscircumferenceflexed - footbreadthhorizontal --> 0.643231
# Multicolinearity alert in between --> bicepscircumferenceflexed - forearmcircumferenceflexed --> 0.912778
# Multicolinearity alert in between --> bicepscircumferenceflexed - forearmforearmbreadth --> 0.857749
# Multicolinearity alert in between --> bicepscircumferenceflexed - handbreadth --> 0.671918
# Multicolinearity alert in between --> bicepscircumferenceflexed - handcircumference --> 0.710117
# Multicolinearity alert in between --> bicepscircumferenceflexed - heelanklecircumference --> 0.703937
# Multicolinearity alert in between --> bicepscircumferenceflexed - interscyei --> 0.703077
# Multicolinearity alert in between --> bicepscircumferenceflexed - interscyeii --> 0.677701
# Multicolinearity alert in between --> bicepscircumferenceflexed - lowerthighcircumference --> 0.664681
# Multicolinearity alert in between --> bicepscircumferenceflexed - neckcircumference --> 0.815731
# Multicolinearity alert in between --> bicepscircumferenceflexed - neckcircumferencebase --> 0.796208
# Multicolinearity alert in between --> bicepscircumferenceflexed - shouldercircumference --> 0.855361
# Multicolinearity alert in between --> bicepscircumferenceflexed - sleevelengthspinewrist --> 0.643841
# Multicolinearity alert in between --> bicepscircumferenceflexed - thighcircumference --> 0.681013
# Multicolinearity alert in between --> bicepscircumferenceflexed - thighclearance --> 0.776805
# Multicolinearity alert in between --> bicepscircumferenceflexed - verticaltrunkcircumferenceusa --> 0.730602
# Multicolinearity alert in between --> bicepscircumferenceflexed - waistbacklength --> 0.606655
# Multicolinearity alert in between --> bicepscircumferenceflexed - waistbreadth --> 0.711718
# Multicolinearity alert in between --> bicepscircumferenceflexed - waistcircumference --> 0.727263
# Multicolinearity alert in between --> bicepscircumferenceflexed - waistdepth --> 0.695867
# Multicolinearity alert in between --> bicepscircumferenceflexed - weightkg --> 0.875365
# Multicolinearity alert in between --> bicepscircumferenceflexed - wristcircumference --> 0.760451
# Multicolinearity alert in between --> bicristalbreadth - buttockcircumference --> 0.646709
# Multicolinearity alert in between --> bicristalbreadth - hipbreadth --> 0.686619
# Multicolinearity alert in between --> bicristalbreadth - waistbreadth --> 0.704269
# Multicolinearity alert in between --> bicristalbreadth - waistcircumference --> 0.631273
# Multicolinearity alert in between --> bideltoidbreadth - abdominalextensiondepthsitting --> 0.724344
# Multicolinearity alert in between --> bideltoidbreadth - acromialheight --> 0.62849
# Multicolinearity alert in between --> bideltoidbreadth - anklecircumference --> 0.641173
# Multicolinearity alert in between --> bideltoidbreadth - balloffootcircumference --> 0.7156
# Multicolinearity alert in between --> bideltoidbreadth - balloffootlength --> 0.631668
# Multicolinearity alert in between --> bideltoidbreadth - biacromialbreadth --> 0.825971
# Multicolinearity alert in between --> bideltoidbreadth - bicepscircumferenceflexed --> 0.874071
# Multicolinearity alert in between --> bideltoidbreadth - bimalleolarbreadth --> 0.659323
# Multicolinearity alert in between --> bideltoidbreadth - bitragionchinarc --> 0.719651
# Multicolinearity alert in between --> bideltoidbreadth - bitragionsubmandibulararc --> 0.769003
# Multicolinearity alert in between --> bideltoidbreadth - bizygomaticbreadth --> 0.704496
# Multicolinearity alert in between --> bideltoidbreadth - buttockdepth --> 0.700968
# Multicolinearity alert in between --> bideltoidbreadth - calfcircumference --> 0.685627
# Multicolinearity alert in between --> bideltoidbreadth - cervicaleheight --> 0.641289
# Multicolinearity alert in between --> bideltoidbreadth - chestbreadth --> 0.811
# Multicolinearity alert in between --> bideltoidbreadth - chestcircumference --> 0.897911
# Multicolinearity alert in between --> bideltoidbreadth - chestdepth --> 0.633978
# Multicolinearity alert in between --> bideltoidbreadth - chestheight --> 0.61384
# Multicolinearity alert in between --> bideltoidbreadth - footbreadthhorizontal --> 0.68886
# Multicolinearity alert in between --> bideltoidbreadth - footlength --> 0.648327
# Multicolinearity alert in between --> bideltoidbreadth - forearmcenterofgriplength --> 0.61953
# Multicolinearity alert in between --> bideltoidbreadth - forearmcircumferenceflexed --> 0.871039
# Multicolinearity alert in between --> bideltoidbreadth - forearmforearmbreadth --> 0.928047
# Multicolinearity alert in between --> bideltoidbreadth - forearmhandlength --> 0.604322
# Multicolinearity alert in between --> bideltoidbreadth - functionalleglength --> 0.636604
# Multicolinearity alert in between --> bideltoidbreadth - handbreadth --> 0.715293
# Multicolinearity alert in between --> bideltoidbreadth - handcircumference --> 0.751763
# Multicolinearity alert in between --> bideltoidbreadth - heelanklecircumference --> 0.755998
# Multicolinearity alert in between --> bideltoidbreadth - interscyei --> 0.817943
# Multicolinearity alert in between --> bideltoidbreadth - interscyeii --> 0.816216
# Multicolinearity alert in between --> bideltoidbreadth - kneeheightsitting --> 0.611419
# Multicolinearity alert in between --> bideltoidbreadth - lowerthighcircumference --> 0.601498
# Multicolinearity alert in between --> bideltoidbreadth - neckcircumference --> 0.868666
# Multicolinearity alert in between --> bideltoidbreadth - neckcircumferencebase --> 0.859566
# Multicolinearity alert in between --> bideltoidbreadth - overheadfingertipreachsitting --> 0.630159
# Multicolinearity alert in between --> bideltoidbreadth - shouldercircumference --> 0.947405
# Multicolinearity alert in between --> bideltoidbreadth - sleevelengthspinewrist --> 0.758664
# Multicolinearity alert in between --> bideltoidbreadth - span --> 0.641681
# Multicolinearity alert in between --> bideltoidbreadth - stature --> 0.621284
# Multicolinearity alert in between --> bideltoidbreadth - suprasternaleheight --> 0.639515
# Multicolinearity alert in between --> bideltoidbreadth - thighcircumference --> 0.626111
# Multicolinearity alert in between --> bideltoidbreadth - thighclearance --> 0.74703
# Multicolinearity alert in between --> bideltoidbreadth - thumbtipreach --> 0.617446
# Multicolinearity alert in between --> bideltoidbreadth - verticaltrunkcircumferenceusa --> 0.804053
# Multicolinearity alert in between --> bideltoidbreadth - waistbacklength --> 0.695057
# Multicolinearity alert in between --> bideltoidbreadth - waistbreadth --> 0.769526
# Multicolinearity alert in between --> bideltoidbreadth - waistcircumference --> 0.775167
# Multicolinearity alert in between --> bideltoidbreadth - waistdepth --> 0.733084
# Multicolinearity alert in between --> bideltoidbreadth - waistfrontlengthsitting --> 0.627193
# Multicolinearity alert in between --> bideltoidbreadth - weightkg --> 0.906437
# Multicolinearity alert in between --> bideltoidbreadth - wristcircumference --> 0.805705
# Multicolinearity alert in between --> bimalleolarbreadth - acromialheight --> 0.705043
# Multicolinearity alert in between --> bimalleolarbreadth - acromionradialelength --> 0.61483
# Multicolinearity alert in between --> bimalleolarbreadth - anklecircumference --> 0.692289
# Multicolinearity alert in between --> bimalleolarbreadth - axillaheight --> 0.675799
# Multicolinearity alert in between --> bimalleolarbreadth - balloffootcircumference --> 0.799207
# Multicolinearity alert in between --> bimalleolarbreadth - balloffootlength --> 0.768204
# Multicolinearity alert in between --> bimalleolarbreadth - biacromialbreadth --> 0.721064
# Multicolinearity alert in between --> bimalleolarbreadth - bideltoidbreadth --> 0.659323
# Multicolinearity alert in between --> bimalleolarbreadth - cervicaleheight --> 0.727401
# Multicolinearity alert in between --> bimalleolarbreadth - chestheight --> 0.723114
# Multicolinearity alert in between --> bimalleolarbreadth - crotchheight --> 0.620476
# Multicolinearity alert in between --> bimalleolarbreadth - eyeheightsitting --> 0.65825
# Multicolinearity alert in between --> bimalleolarbreadth - footbreadthhorizontal --> 0.762344
# Multicolinearity alert in between --> bimalleolarbreadth - footlength --> 0.781766
# Multicolinearity alert in between --> bimalleolarbreadth - forearmcenterofgriplength --> 0.676212
# Multicolinearity alert in between --> bimalleolarbreadth - forearmcircumferenceflexed --> 0.705035
# Multicolinearity alert in between --> bimalleolarbreadth - forearmforearmbreadth --> 0.605838
# Multicolinearity alert in between --> bimalleolarbreadth - forearmhandlength --> 0.694098
# Multicolinearity alert in between --> bimalleolarbreadth - functionalleglength --> 0.67227
# Multicolinearity alert in between --> bimalleolarbreadth - handbreadth --> 0.764196
# Multicolinearity alert in between --> bimalleolarbreadth - handcircumference --> 0.781899
# Multicolinearity alert in between --> bimalleolarbreadth - handlength --> 0.632582
# Multicolinearity alert in between --> bimalleolarbreadth - heelanklecircumference --> 0.834873
# Multicolinearity alert in between --> bimalleolarbreadth - heelbreadth --> 0.610799
# Multicolinearity alert in between --> bimalleolarbreadth - iliocristaleheight --> 0.622955
# Multicolinearity alert in between --> bimalleolarbreadth - interscyeii --> 0.615642
# Multicolinearity alert in between --> bimalleolarbreadth - kneeheightmidpatella --> 0.634618
# Multicolinearity alert in between --> bimalleolarbreadth - kneeheightsitting --> 0.701004
# Multicolinearity alert in between --> bimalleolarbreadth - neckcircumference --> 0.673289
# Multicolinearity alert in between --> bimalleolarbreadth - neckcircumferencebase --> 0.678749
# Multicolinearity alert in between --> bimalleolarbreadth - overheadfingertipreachsitting --> 0.68444
# Multicolinearity alert in between --> bimalleolarbreadth - palmlength --> 0.618911
# Multicolinearity alert in between --> bimalleolarbreadth - poplitealheight --> 0.646501
# Multicolinearity alert in between --> bimalleolarbreadth - radialestylionlength --> 0.641447
# Multicolinearity alert in between --> bimalleolarbreadth - shouldercircumference --> 0.720906
# Multicolinearity alert in between --> bimalleolarbreadth - shoulderelbowlength --> 0.647598
# Multicolinearity alert in between --> bimalleolarbreadth - sittingheight --> 0.67155
# Multicolinearity alert in between --> bimalleolarbreadth - sleevelengthspinewrist --> 0.743372
# Multicolinearity alert in between --> bimalleolarbreadth - sleeveoutseam --> 0.649898
# Multicolinearity alert in between --> bimalleolarbreadth - span --> 0.699099
# Multicolinearity alert in between --> bimalleolarbreadth - stature --> 0.729417
# Multicolinearity alert in between --> bimalleolarbreadth - suprasternaleheight --> 0.722525
# Multicolinearity alert in between --> bimalleolarbreadth - tenthribheight --> 0.629793
# Multicolinearity alert in between --> bimalleolarbreadth - thumbtipreach --> 0.644387
# Multicolinearity alert in between --> bimalleolarbreadth - verticaltrunkcircumferenceusa --> 0.616709
# Multicolinearity alert in between --> bimalleolarbreadth - waistbacklength --> 0.62783
# Multicolinearity alert in between --> bimalleolarbreadth - waistheightomphalion --> 0.64769
# Multicolinearity alert in between --> bimalleolarbreadth - weightkg --> 0.662688
# Multicolinearity alert in between --> bimalleolarbreadth - wristcircumference --> 0.803019
# Multicolinearity alert in between --> bimalleolarbreadth - wristheight --> 0.629313
# Multicolinearity alert in between --> bitragionchinarc - balloffootcircumference --> 0.657071
# Multicolinearity alert in between --> bitragionchinarc - balloffootlength --> 0.616681
# Multicolinearity alert in between --> bitragionchinarc - biacromialbreadth --> 0.669708
# Multicolinearity alert in between --> bitragionchinarc - bicepscircumferenceflexed --> 0.676975
# Multicolinearity alert in between --> bitragionchinarc - bideltoidbreadth --> 0.719651
# Multicolinearity alert in between --> bitragionchinarc - bitragionsubmandibulararc --> 0.852837
# Multicolinearity alert in between --> bitragionchinarc - bizygomaticbreadth --> 0.717879
# Multicolinearity alert in between --> bitragionchinarc - chestcircumference --> 0.655254
# Multicolinearity alert in between --> bitragionchinarc - footbreadthhorizontal --> 0.642138
# Multicolinearity alert in between --> bitragionchinarc - footlength --> 0.641191
# Multicolinearity alert in between --> bitragionchinarc - forearmcenterofgriplength --> 0.63537
# Multicolinearity alert in between --> bitragionchinarc - forearmcircumferenceflexed --> 0.718522
# Multicolinearity alert in between --> bitragionchinarc - forearmforearmbreadth --> 0.670159
# Multicolinearity alert in between --> bitragionchinarc - forearmhandlength --> 0.626094
# Multicolinearity alert in between --> bitragionchinarc - handbreadth --> 0.653821
# Multicolinearity alert in between --> bitragionchinarc - handcircumference --> 0.679085
# Multicolinearity alert in between --> bitragionchinarc - heelanklecircumference --> 0.713509
# Multicolinearity alert in between --> bitragionchinarc - interscyeii --> 0.613852
# Multicolinearity alert in between --> bitragionchinarc - neckcircumference --> 0.740083
# Multicolinearity alert in between --> bitragionchinarc - neckcircumferencebase --> 0.721504
# Multicolinearity alert in between --> bitragionchinarc - shouldercircumference --> 0.742342
# Multicolinearity alert in between --> bitragionchinarc - sleevelengthspinewrist --> 0.669197
# Multicolinearity alert in between --> bitragionchinarc - span --> 0.620954
# Multicolinearity alert in between --> bitragionchinarc - verticaltrunkcircumferenceusa --> 0.621431
# Multicolinearity alert in between --> bitragionchinarc - weightkg --> 0.713572
# Multicolinearity alert in between --> bitragionchinarc - wristcircumference --> 0.696577
# Multicolinearity alert in between --> bitragionsubmandibulararc - abdominalextensiondepthsitting --> 0.626294
# Multicolinearity alert in between --> bitragionsubmandibulararc - balloffootcircumference --> 0.652441
# Multicolinearity alert in between --> bitragionsubmandibulararc - biacromialbreadth --> 0.669106
# Multicolinearity alert in between --> bitragionsubmandibulararc - bicepscircumferenceflexed --> 0.709026
# Multicolinearity alert in between --> bitragionsubmandibulararc - bideltoidbreadth --> 0.769003
# Multicolinearity alert in between --> bitragionsubmandibulararc - bitragionchinarc --> 0.852837
# Multicolinearity alert in between --> bitragionsubmandibulararc - bizygomaticbreadth --> 0.709341
# ...
# Multicolinearity alert in between --> waistheightomphalion - lateralfemoralepicondyleheight --> 0.886198
# Multicolinearity alert in between --> waistheightomphalion - lateralmalleolusheight --> 0.609078
# Multicolinearity alert in between --> waistheightomphalion - overheadfingertipreachsitting --> 0.808129
# Multicolinearity alert in between --> waistheightomphalion - palmlength --> 0.691663
# Multicolinearity alert in between --> waistheightomphalion - poplitealheight --> 0.928067
# Multicolinearity alert in between --> waistheightomphalion - radialestylionlength --> 0.831817
# Multicolinearity alert in between --> waistheightomphalion - shoulderelbowlength --> 0.869395
# Multicolinearity alert in between --> waistheightomphalion - sittingheight --> 0.710939
# Multicolinearity alert in between --> waistheightomphalion - sleevelengthspinewrist --> 0.836181
# Multicolinearity alert in between --> waistheightomphalion - sleeveoutseam --> 0.87704
# Multicolinearity alert in between --> waistheightomphalion - span --> 0.880795
# Multicolinearity alert in between --> waistheightomphalion - stature --> 0.935163
# Multicolinearity alert in between --> waistheightomphalion - suprasternaleheight --> 0.938366
# Multicolinearity alert in between --> waistheightomphalion - tenthribheight --> 0.940738
# Multicolinearity alert in between --> waistheightomphalion - thumbtipreach --> 0.777009
# Multicolinearity alert in between --> waistheightomphalion - tibialheight --> 0.909651
# Multicolinearity alert in between --> waistheightomphalion - trochanterionheight --> 0.909454
# Multicolinearity alert in between --> waistheightomphalion - wristcircumference --> 0.632789
# Multicolinearity alert in between --> waistheightomphalion - wristheight --> 0.812746
# Multicolinearity alert in between --> weightkg - abdominalextensiondepthsitting --> 0.825198
# Multicolinearity alert in between --> weightkg - acromialheight --> 0.677768
# Multicolinearity alert in between --> weightkg - anklecircumference --> 0.741326
# Multicolinearity alert in between --> weightkg - axillaheight --> 0.613565
# Multicolinearity alert in between --> weightkg - balloffootcircumference --> 0.73092
# Multicolinearity alert in between --> weightkg - balloffootlength --> 0.645382
# Multicolinearity alert in between --> weightkg - biacromialbreadth --> 0.703679
# Multicolinearity alert in between --> weightkg - bicepscircumferenceflexed --> 0.875365
# Multicolinearity alert in between --> weightkg - bideltoidbreadth --> 0.906437
# Multicolinearity alert in between --> weightkg - bimalleolarbreadth --> 0.662688
# Multicolinearity alert in between --> weightkg - bitragionchinarc --> 0.713572
# Multicolinearity alert in between --> weightkg - bitragionsubmandibulararc --> 0.766438
# Multicolinearity alert in between --> weightkg - bizygomaticbreadth --> 0.680653
# Multicolinearity alert in between --> weightkg - buttockcircumference --> 0.76997
# Multicolinearity alert in between --> weightkg - buttockdepth --> 0.835051
# Multicolinearity alert in between --> weightkg - buttockkneelength --> 0.714019
# Multicolinearity alert in between --> weightkg - calfcircumference --> 0.81806
# Multicolinearity alert in between --> weightkg - cervicaleheight --> 0.672614
# Multicolinearity alert in between --> weightkg - chestbreadth --> 0.768326
# Multicolinearity alert in between --> weightkg - chestcircumference --> 0.915082
# Multicolinearity alert in between --> weightkg - chestdepth --> 0.758555
# Multicolinearity alert in between --> weightkg - chestheight --> 0.631227
# Multicolinearity alert in between --> weightkg - footbreadthhorizontal --> 0.703101
# Multicolinearity alert in between --> weightkg - footlength --> 0.661118
# Multicolinearity alert in between --> weightkg - forearmcenterofgriplength --> 0.633257
# Multicolinearity alert in between --> weightkg - forearmcircumferenceflexed --> 0.856894
# Multicolinearity alert in between --> weightkg - forearmforearmbreadth --> 0.872375
# Multicolinearity alert in between --> weightkg - forearmhandlength --> 0.618887
# Multicolinearity alert in between --> weightkg - functionalleglength --> 0.684454
# Multicolinearity alert in between --> weightkg - handbreadth --> 0.687194
# Multicolinearity alert in between --> weightkg - handcircumference --> 0.72039
# Multicolinearity alert in between --> weightkg - heelanklecircumference --> 0.792356
# Multicolinearity alert in between --> weightkg - heelbreadth --> 0.610165
# Multicolinearity alert in between --> weightkg - hipbreadth --> 0.609747
# Multicolinearity alert in between --> weightkg - interscyei --> 0.741561
# Multicolinearity alert in between --> weightkg - interscyeii --> 0.729566
# Multicolinearity alert in between --> weightkg - kneeheightsitting --> 0.661833
# Multicolinearity alert in between --> weightkg - lowerthighcircumference --> 0.777924
# Multicolinearity alert in between --> weightkg - neckcircumference --> 0.823614
# Multicolinearity alert in between --> weightkg - neckcircumferencebase --> 0.815481
# Multicolinearity alert in between --> weightkg - overheadfingertipreachsitting --> 0.630798
# Multicolinearity alert in between --> weightkg - shouldercircumference --> 0.870692
# Multicolinearity alert in between --> weightkg - sittingheight --> 0.600218
# Multicolinearity alert in between --> weightkg - sleevelengthspinewrist --> 0.732649
# Multicolinearity alert in between --> weightkg - span --> 0.633863
# Multicolinearity alert in between --> weightkg - stature --> 0.653154
# Multicolinearity alert in between --> weightkg - suprasternaleheight --> 0.683296
# Multicolinearity alert in between --> weightkg - tenthribheight --> 0.610239
# Multicolinearity alert in between --> weightkg - thighcircumference --> 0.79163
# Multicolinearity alert in between --> weightkg - thighclearance --> 0.844685
# Multicolinearity alert in between --> weightkg - thumbtipreach --> 0.641816
# Multicolinearity alert in between --> weightkg - verticaltrunkcircumferenceusa --> 0.900088
# Multicolinearity alert in between --> weightkg - waistbacklength --> 0.724779
# Multicolinearity alert in between --> weightkg - waistbreadth --> 0.858881
# Multicolinearity alert in between --> weightkg - waistcircumference --> 0.872855
# Multicolinearity alert in between --> weightkg - waistdepth --> 0.830974
# Multicolinearity alert in between --> weightkg - waistfrontlengthsitting --> 0.679795
# Multicolinearity alert in between --> weightkg - wristcircumference --> 0.798308
# Multicolinearity alert in between --> weightkg - wristheight --> 0.665846
# Multicolinearity alert in between --> wristcircumference - acromialheight --> 0.733564
# Multicolinearity alert in between --> wristcircumference - acromionradialelength --> 0.642518
# Multicolinearity alert in between --> wristcircumference - anklecircumference --> 0.697485
# Multicolinearity alert in between --> wristcircumference - axillaheight --> 0.685336
# Multicolinearity alert in between --> wristcircumference - balloffootcircumference --> 0.827143
# Multicolinearity alert in between --> wristcircumference - balloffootlength --> 0.74323
# Multicolinearity alert in between --> wristcircumference - biacromialbreadth --> 0.803051
# Multicolinearity alert in between --> wristcircumference - bicepscircumferenceflexed --> 0.760451
# Multicolinearity alert in between --> wristcircumference - bideltoidbreadth --> 0.805705
# Multicolinearity alert in between --> wristcircumference - bimalleolarbreadth --> 0.803019
# Multicolinearity alert in between --> wristcircumference - bitragionchinarc --> 0.696577
# Multicolinearity alert in between --> wristcircumference - bitragionsubmandibulararc --> 0.728897
# Multicolinearity alert in between --> wristcircumference - bizygomaticbreadth --> 0.669909
# Multicolinearity alert in between --> wristcircumference - calfcircumference --> 0.607832
# Multicolinearity alert in between --> wristcircumference - cervicaleheight --> 0.756999
# Multicolinearity alert in between --> wristcircumference - chestbreadth --> 0.643212
# Multicolinearity alert in between --> wristcircumference - chestcircumference --> 0.715428
# Multicolinearity alert in between --> wristcircumference - chestheight --> 0.74047
# Multicolinearity alert in between --> wristcircumference - crotchheight --> 0.60202
# Multicolinearity alert in between --> wristcircumference - eyeheightsitting --> 0.709742
# Multicolinearity alert in between --> wristcircumference - footbreadthhorizontal --> 0.78611
# Multicolinearity alert in between --> wristcircumference - footlength --> 0.777983
# Multicolinearity alert in between --> wristcircumference - forearmcenterofgriplength --> 0.733332
# Multicolinearity alert in between --> wristcircumference - forearmcircumferenceflexed --> 0.871995
# Multicolinearity alert in between --> wristcircumference - forearmforearmbreadth --> 0.767857
# Multicolinearity alert in between --> wristcircumference - forearmhandlength --> 0.730333
# Multicolinearity alert in between --> wristcircumference - functionalleglength --> 0.697662
# Multicolinearity alert in between --> wristcircumference - handbreadth --> 0.868492
# Multicolinearity alert in between --> wristcircumference - handcircumference --> 0.900651
# Multicolinearity alert in between --> wristcircumference - handlength --> 0.679226
# Multicolinearity alert in between --> wristcircumference - heelanklecircumference --> 0.863887
# Multicolinearity alert in between --> wristcircumference - iliocristaleheight --> 0.633664
# Multicolinearity alert in between --> wristcircumference - interscyei --> 0.688629
# Multicolinearity alert in between --> wristcircumference - interscyeii --> 0.722928
# Multicolinearity alert in between --> wristcircumference - kneeheightmidpatella --> 0.638435
# Multicolinearity alert in between --> wristcircumference - kneeheightsitting --> 0.716532
# Multicolinearity alert in between --> wristcircumference - lateralmalleolusheight --> 0.682508
# Multicolinearity alert in between --> wristcircumference - neckcircumference --> 0.838993
# Multicolinearity alert in between --> wristcircumference - neckcircumferencebase --> 0.837021
# Multicolinearity alert in between --> wristcircumference - overheadfingertipreachsitting --> 0.740391
# Multicolinearity alert in between --> wristcircumference - palmlength --> 0.647952
# Multicolinearity alert in between --> wristcircumference - poplitealheight --> 0.630229
# Multicolinearity alert in between --> wristcircumference - radialestylionlength --> 0.669373
# Multicolinearity alert in between --> wristcircumference - shouldercircumference --> 0.853879
# Multicolinearity alert in between --> wristcircumference - shoulderelbowlength --> 0.68141
# Multicolinearity alert in between --> wristcircumference - sittingheight --> 0.710539
# Multicolinearity alert in between --> wristcircumference - sleevelengthspinewrist --> 0.802357
# Multicolinearity alert in between --> wristcircumference - sleeveoutseam --> 0.663171
# Multicolinearity alert in between --> wristcircumference - span --> 0.741029
# Multicolinearity alert in between --> wristcircumference - stature --> 0.749021
# Multicolinearity alert in between --> wristcircumference - suprasternaleheight --> 0.751616
# Multicolinearity alert in between --> wristcircumference - tenthribheight --> 0.634188
# Multicolinearity alert in between --> wristcircumference - thighclearance --> 0.613603
# Multicolinearity alert in between --> wristcircumference - thumbtipreach --> 0.695585
# Multicolinearity alert in between --> wristcircumference - tibialheight --> 0.601635
# Multicolinearity alert in between --> wristcircumference - verticaltrunkcircumferenceusa --> 0.746929
# Multicolinearity alert in between --> wristcircumference - waistbacklength --> 0.723534
# Multicolinearity alert in between --> wristcircumference - waistfrontlengthsitting --> 0.617985
# Multicolinearity alert in between --> wristcircumference - waistheightomphalion --> 0.632789
# Multicolinearity alert in between --> wristcircumference - weightkg --> 0.798308
# Multicolinearity alert in between --> wristcircumference - wristheight --> 0.663459
# Multicolinearity alert in between --> wristheight - acromialheight --> 0.921268
# Multicolinearity alert in between --> wristheight - acromionradialelength --> 0.67714
# Multicolinearity alert in between --> wristheight - axillaheight --> 0.903063
# Multicolinearity alert in between --> wristheight - balloffootcircumference --> 0.62962
# Multicolinearity alert in between --> wristheight - balloffootlength --> 0.683307
# Multicolinearity alert in between --> wristheight - biacromialbreadth --> 0.621811
# Multicolinearity alert in between --> wristheight - bimalleolarbreadth --> 0.629313
# Multicolinearity alert in between --> wristheight - buttockheight --> 0.74143
# Multicolinearity alert in between --> wristheight - buttockkneelength --> 0.714287
# Multicolinearity alert in between --> wristheight - buttockpopliteallength --> 0.643402
# Multicolinearity alert in between --> wristheight - cervicaleheight --> 0.890318
# Multicolinearity alert in between --> wristheight - chestheight --> 0.862311
# Multicolinearity alert in between --> wristheight - crotchheight --> 0.754959
# Multicolinearity alert in between --> wristheight - eyeheightsitting --> 0.80476
# Multicolinearity alert in between --> wristheight - footlength --> 0.708357
# Multicolinearity alert in between --> wristheight - forearmcenterofgriplength --> 0.663682
# Multicolinearity alert in between --> wristheight - forearmhandlength --> 0.678806
# Multicolinearity alert in between --> wristheight - functionalleglength --> 0.777978
# Multicolinearity alert in between --> wristheight - handbreadth --> 0.625023
# Multicolinearity alert in between --> wristheight - handcircumference --> 0.632694
# Multicolinearity alert in between --> wristheight - handlength --> 0.623739
# Multicolinearity alert in between --> wristheight - heelanklecircumference --> 0.711217
# Multicolinearity alert in between --> wristheight - iliocristaleheight --> 0.81747
# Multicolinearity alert in between --> wristheight - kneeheightmidpatella --> 0.765945
# Multicolinearity alert in between --> wristheight - kneeheightsitting --> 0.806874
# Multicolinearity alert in between --> wristheight - lateralfemoralepicondyleheight --> 0.735543
# Multicolinearity alert in between --> wristheight - lateralmalleolusheight --> 0.633432
# Multicolinearity alert in between --> wristheight - neckcircumferencebase --> 0.600909
# Multicolinearity alert in between --> wristheight - overheadfingertipreachsitting --> 0.741697
# Multicolinearity alert in between --> wristheight - poplitealheight --> 0.752419
# Multicolinearity alert in between --> wristheight - radialestylionlength --> 0.610389
# Multicolinearity alert in between --> wristheight - shouldercircumference --> 0.61607
# Multicolinearity alert in between --> wristheight - shoulderelbowlength --> 0.695203
# Multicolinearity alert in between --> wristheight - sittingheight --> 0.811799
# Multicolinearity alert in between --> wristheight - sleevelengthspinewrist --> 0.704643
# Multicolinearity alert in between --> wristheight - sleeveoutseam --> 0.66003
# Multicolinearity alert in between --> wristheight - span --> 0.688639
# Multicolinearity alert in between --> wristheight - stature --> 0.89104
# Multicolinearity alert in between --> wristheight - suprasternaleheight --> 0.897065
# Multicolinearity alert in between --> wristheight - tenthribheight --> 0.848566
# Multicolinearity alert in between --> wristheight - thumbtipreach --> 0.63282
# Multicolinearity alert in between --> wristheight - tibialheight --> 0.763668
# Multicolinearity alert in between --> wristheight - trochanterionheight --> 0.752367
# Multicolinearity alert in between --> wristheight - verticaltrunkcircumferenceusa --> 0.766192
# Multicolinearity alert in between --> wristheight - waistbacklength --> 0.701594
# Multicolinearity alert in between --> wristheight - waistfrontlengthsitting --> 0.617996
# Multicolinearity alert in between --> wristheight - waistheightomphalion --> 0.812746
# Multicolinearity alert in between --> wristheight - weightkg --> 0.665846
# Multicolinearity alert in between --> wristheight - wristcircumference --> 0.663459

# %%
df.select_dtypes("object")
# Out:
#       gender subjectsbirthlocation   dodrace writingpreference
# 0     Female               Germany     Black        Right hand
# 1     Female            California  Hispanic        Right hand
# 2     Female                 Texas     White        Right hand
# 3     Female  District of Columbia     Black        Right hand
# 4     Female                 Texas     White        Right hand
# ...      ...                   ...       ...               ...
# 6063    Male              Colorado     White        Right hand
# 6064    Male              Oklahoma     White        Right hand
# 6065    Male              Oklahoma     White        Right hand
# 6066    Male              Oklahoma     White        Right hand
# 6067    Male              Oklahoma     White        Right hand
#
# [5769 rows x 4 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,classification_report
from sklearn.model_selection import cross_validate
from sklearn.metrics import accuracy_score, f1_score, recall_score,\
                            precision_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, auc, roc_curve, RocCurveDisplay, PrecisionRecallDisplay
from scikitplot.metrics import plot_roc_curve, plot_precision_recall_curve
from yellowbrick.model_selection import FeatureImportances 
from sklearn.linear_model import Ridge

# %%
X = df.drop(columns="dodrace")
y = df['dodrace']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify = y)

# %%
print("X_train shape : ", X_train.shape)
print("y_train shape   : ", y_train.shape)
print("X_test shape  : ", X_test.shape)
print("y_test shape    : ", y_test.shape)
# Out:
# X_train shape :  (4615, 97)
# y_train shape   :  (4615,)
# X_test shape  :  (1154, 97)
# y_test shape    :  (1154,)

# %%
scaler = StandardScaler()

# %%
cat = X_train.select_dtypes("object").columns
cat
# Out:
# Index(['gender', 'subjectsbirthlocation', 'writingpreference'], dtype='object')

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), remainder=StandardScaler())

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %%
from sklearn.pipeline import Pipeline

# %%
operations = [("OneHotEncoder", column_trans), ("logistic", LogisticRegression())]

pipe_log_model = Pipeline(steps=operations)

pipe_log_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=StandardScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['gender', 'subjectsbirthlocation', 'writingpreference'], dtype='object'))])),
#                 ('logistic', LogisticRegression())])

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
pipe_log_model.fit(X_train,y_train)
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[239   5  16]
#  [ 15  79  42]
#  [  5  29 724]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.92      0.92       260
#     Hispanic       0.70      0.58      0.63       136
#        White       0.93      0.96      0.94       758
#
#     accuracy                           0.90      1154
#    macro avg       0.85      0.82      0.83      1154
# weighted avg       0.90      0.90      0.90      1154
#
#
# Train_Set
# [[ 973    7   58]
#  [  23  333  187]
#  [  29   65 2940]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.94      0.94      1038
#     Hispanic       0.82      0.61      0.70       543
#        White       0.92      0.97      0.95      3034
#
#     accuracy                           0.92      4615
#    macro avg       0.90      0.84      0.86      4615
# weighted avg       0.92      0.92      0.92      4615

# %%
ConfusionMatrixDisplay.from_estimator(pipe_log_model,X_test, y_test,normalize='all')

# %% [markdown]
# ## Cross Validation

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), remainder=MinMaxScaler())
operations = [("OneHotEncoder", column_trans), ("logistic", LogisticRegression())]
model = Pipeline(steps=operations)
scores = cross_validate(model, X_train, y_train, scoring = ["accuracy", "precision_weighted", "recall_weighted", "f1_weighted"], 
                        cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy               0.900318
# train_accuracy              0.915613
# test_precision_weighted     0.897158
# train_precision_weighted    0.913099
# test_recall_weighted        0.900318
# train_recall_weighted       0.915613
# test_f1_weighted            0.894361
# train_f1_weighted           0.910922
# dtype: float64

# %% [markdown]
# ## Cross Validation for Hispanic Class

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), remainder=MinMaxScaler())
operations = [("OneHotEncoder", column_trans), ("logistic", LogisticRegression())]
model = Pipeline(steps=operations)
f1_hispanic = make_scorer(f1_score, average = None, labels =["Hispanic"])
precision_hispanic = make_scorer(precision_score, average = None, labels =["Hispanic"])
recall_hispanic = make_scorer(recall_score, average = None, labels =["Hispanic"])
cv = 10 
scoring = {"precision_hispanic": precision_hispanic, 
           "recall_hispanic": recall_hispanic, 
           "f1_hispanic": f1_hispanic}

# %%
scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = cv, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_precision_hispanic     0.792624
# train_precision_hispanic    0.835302
# test_recall_hispanic        0.530337
# train_recall_hispanic       0.579903
# test_f1_hispanic            0.632040
# train_f1_hispanic           0.684514
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), remainder=MinMaxScaler())
operations = [("OneHotEncoder", column_trans), ("logistic", LogisticRegression())]
model = Pipeline(steps=operations)
penalty = ["l1","l2", None]
C = [0.5, 0.7, 1]
solver = ["lbfgs", "liblinear"]  
class_weight= ["balanced", None]
cv = 5
recall_hispanic = make_scorer(recall_score, average = None, labels =["Hispanic"])
param_grid = {"logistic__penalty" : penalty,
              "logistic__C" : C,
              "logistic__class_weight":class_weight,
              "logistic__solver":solver}

# %%
grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          cv=cv,
                          scoring = recall_hispanic,
                          n_jobs = -1,
                          return_train_score=True)

# %%
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['gender', 'subjectsbirthlocation', 'writingpreference'], dtype='object'))])),
#                                        ('logistic', LogisticRegression())]),
#              n_jobs=-1,
#              param_grid={'logistic__C': [0.5, 0.7, 1],
#                          'logistic__class_weight': ['balanced', None],
#                          'logistic__penalty': ['l1', 'l2', None],
#                          'logistic__solver': ['lbfgs', 'liblinear']},
#              return_train_score=True,
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']))

# %%
grid_model.best_params_
# Out:
# {'logistic__C': 1,
#  'logistic__class_weight': 'balanced',
#  'logistic__penalty': 'l2',
#  'logistic__solver': 'lbfgs'}

# %%
eval_metric(grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[240  11   9]
#  [ 13 102  21]
#  [ 10  93 655]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.92      0.92       260
#     Hispanic       0.50      0.75      0.60       136
#        White       0.96      0.86      0.91       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.85      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 975   33   30]
#  [  14  463   66]
#  [  69  350 2615]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.94      0.93      1038
#     Hispanic       0.55      0.85      0.67       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.84      4615
# weighted avg       0.91      0.88      0.89      4615

# %%
ConfusionMatrixDisplay.from_estimator(grid_model,X_test, y_test,normalize='all')

# %% [markdown]
# ## ROC (Receiver Operating Curve) and AUC (Area Under Curve)

# %%
y_pred_proba = grid_model.predict_proba(X_test)
    
plot_roc_curve(y_test, y_pred_proba)
plt.show();

# %%
from sklearn.metrics import average_precision_score, roc_auc_score

y_test_dummies = pd.get_dummies(y_test).values

roc_auc_score(y_test_dummies[:, 1], y_pred_proba[:, 1])  
# roc_auc score  for hispanic
# Out:
# 0.906867560383682

# %% [markdown]
# ##  Precision Recall Curve

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve
from scikitplot.metrics import plot_precision_recall  
plot_precision_recall(y_test, y_pred_proba)
plt.show();

# %%
from sklearn.metrics import average_precision_score, roc_auc_score

y_test_dummies = pd.get_dummies(y_test).values

average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
# precision-recall  for hispanic
# Out:
# 0.6841611145715141

# %% [markdown]
# ## 2. SVC

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix

# %%
fig = plt.figure(figsize=(10,100))

for i, col in enumerate(df.columns[:-1]):
    if i < 93:
        plt.subplot(31,3,i+1)
        ax = sns.boxplot(x="dodrace", y=df[col], data=df)

plt.tight_layout();

# %% [markdown]
# ### Vanilla SVC model

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), remainder=StandardScaler())
operations = [("OneHot_Ordinal_Encoder", column_trans), ("svc_vanilla", SVC())]
svc_vanilla_pipe = Pipeline(steps=operations)
svc_vanilla_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHot_Ordinal_Encoder',
#                  ColumnTransformer(remainder=StandardScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['gender', 'subjectsbirthlocation', 'writingpreference'], dtype='object'))])),
#                 ('svc_vanilla', SVC())])

# %%
y_pred = svc_vanilla_pipe.predict(X_test)
y_pred
# Out:
# array(['Black', 'White', 'White', ..., 'Black', 'White', 'White'],
#       dtype=object)

# %%
eval_metric(svc_vanilla_pipe, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[239   3  18]
#  [ 13  30  93]
#  [  5   9 744]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.92      0.92       260
#     Hispanic       0.71      0.22      0.34       136
#        White       0.87      0.98      0.92       758
#
#     accuracy                           0.88      1154
#    macro avg       0.84      0.71      0.73      1154
# weighted avg       0.87      0.88      0.85      1154
#
#
# Train_Set
# [[ 969    6   63]
#  [  43  169  331]
#  [  14    9 3011]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.93      0.94      1038
#     Hispanic       0.92      0.31      0.46       543
#        White       0.88      0.99      0.94      3034
#
#     accuracy                           0.90      4615
#    macro avg       0.92      0.75      0.78      4615
# weighted avg       0.90      0.90      0.88      4615

# %% [markdown]
# ## Cross Validation

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), remainder=StandardScaler())
operations = [("OneHotEncoder", column_trans), (("SVC", SVC()))]
model = Pipeline(steps=operations)

recall_hispanic = make_scorer(recall_score, average = None, labels =["Hispanic"])

scoring = {"recall_hispanic": recall_hispanic}
scores = cross_validate(model, X_train, y_train, scoring = scoring, 
                        cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_recall_hispanic     0.222828
# train_recall_hispanic    0.312864
# dtype: float64

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), remainder=StandardScaler())
operations = [("OneHot_Ordinal_Encoder", column_trans), ("SVC", SVC(class_weight="balanced",random_state=42))]
svc_pipe = Pipeline(steps=operations)
param_grid = {'SVC__C':[0.01, 0.1],
              'SVC__kernel':['linear','rbf'],
              'SVC__gamma':["scale"],
              'SVC__degree':[2,3],
              'SVC__class_weight': [None, 'balanced']}
svc_grid_model = GridSearchCV(svc_pipe, param_grid = param_grid, scoring=recall_hispanic, cv=5, return_train_score=True, n_jobs=-1)
svc_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OneHot_Ordinal_Encoder',
#                                         ColumnTransformer(remainder=StandardScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['gender', 'subjectsbirthlocation', 'writingpreference'], dtype='object'))])),
#                                        ('SVC',
#                                         SVC(class_weight='balanced',
#                                             random_state=42))]),
#              n_jobs=-1,
#              param_grid={'SVC__C': [0.01, 0.1],
#                          'SVC__class_weight': [None, 'balanced'],
#                          'SVC__degree': [2, 3], 'SVC__gamma': ['scale'],
#                          'SVC__kernel': ['linear', 'rbf']},
#              return_train_score=True,
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']))

# %%
svc_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OneHot_Ordinal_Encoder',
#                  ColumnTransformer(remainder=StandardScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['gender', 'subjectsbirthlocation', 'writingpreference'], dtype='object'))])),
#                 ('SVC',
#                  SVC(C=0.1, class_weight='balanced', degree=2, kernel='linear',
#                      random_state=42))])

# %%
svc_grid_model.best_params_
# Out:
# {'SVC__C': 0.1,
#  'SVC__class_weight': 'balanced',
#  'SVC__degree': 2,
#  'SVC__gamma': 'scale',
#  'SVC__kernel': 'linear'}

# %%
pd.DataFrame(svc_grid_model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_SVC__C  \
# 0        5.801103      0.225179         1.581059        0.298564         0.01
# 1       10.320022      2.172156         3.242973        1.550048         0.01
# 2        5.695289      0.938383         1.020832        0.249851         0.01
# 3       11.670060      1.563297         3.703390        1.289151         0.01
# 4        8.281771      0.619565         1.420336        0.129227         0.01
# 5       21.976899      4.032967         5.172749        2.238709         0.01
# 6        7.745013      1.840195         1.203415        0.215533         0.01
# 7       20.414558      2.459246         5.260954        2.080514         0.01
# 8        4.153184      0.385027         0.591975        0.086463          0.1
# 9        8.565455      1.291844         3.111605        1.379820          0.1
# 10       4.498012      0.623412         0.674238        0.150084          0.1
# 11      10.148069      1.355397         3.341302        1.454655          0.1
# 12       6.359806      0.751169         0.977538        0.207252          0.1
# 13      12.082082      2.334762         3.766723        1.652459          0.1
# 14       4.013712      0.668427         0.625223        0.167351          0.1
# 15      10.597139      2.278353         3.309114        1.630832          0.1
#
#    param_SVC__class_weight param_SVC__degree param_SVC__gamma  \
# 0                     None                 2            scale
# 1                     None                 2            scale
# 2                     None                 3            scale
# 3                     None                 3            scale
# 4                 balanced                 2            scale
# 5                 balanced                 2            scale
# 6                 balanced                 3            scale
# 7                 balanced                 3            scale
# 8                     None                 2            scale
# 9                     None                 2            scale
# 10                    None                 3            scale
# 11                    None                 3            scale
# 12                balanced                 2            scale
# 13                balanced                 2            scale
# 14                balanced                 3            scale
# 15                balanced                 3            scale
#
#    param_SVC__kernel                                             params  ...  \
# 0             linear  {'SVC__C': 0.01, 'SVC__class_weight': None, 'S...  ...
# 1                rbf  {'SVC__C': 0.01, 'SVC__class_weight': None, 'S...  ...
# 2             linear  {'SVC__C': 0.01, 'SVC__class_weight': None, 'S...  ...
# 3                rbf  {'SVC__C': 0.01, 'SVC__class_weight': None, 'S...  ...
# 4             linear  {'SVC__C': 0.01, 'SVC__class_weight': 'balance...  ...
# 5                rbf  {'SVC__C': 0.01, 'SVC__class_weight': 'balance...  ...
# 6             linear  {'SVC__C': 0.01, 'SVC__class_weight': 'balance...  ...
# 7                rbf  {'SVC__C': 0.01, 'SVC__class_weight': 'balance...  ...
# 8             linear  {'SVC__C': 0.1, 'SVC__class_weight': None, 'SV...  ...
# 9                rbf  {'SVC__C': 0.1, 'SVC__class_weight': None, 'SV...  ...
# 10            linear  {'SVC__C': 0.1, 'SVC__class_weight': None, 'SV...  ...
# 11               rbf  {'SVC__C': 0.1, 'SVC__class_weight': None, 'SV...  ...
# 12            linear  {'SVC__C': 0.1, 'SVC__class_weight': 'balanced...  ...
# 13               rbf  {'SVC__C': 0.1, 'SVC__class_weight': 'balanced...  ...
# 14            linear  {'SVC__C': 0.1, 'SVC__class_weight': 'balanced...  ...
# 15               rbf  {'SVC__C': 0.1, 'SVC__class_weight': 'balanced...  ...
#
#     mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0          0.224635        0.016462               11            0.206897
# 1          0.000000        0.000000               13            0.000000
# 2          0.224635        0.016462               11            0.206897
# 3          0.000000        0.000000               13            0.000000
# 4          0.721916        0.013426                3            0.777011
# 5          0.565375        0.037888                7            0.537931
# 6          0.721916        0.013426                3            0.777011
# 7          0.565375        0.037888                7            0.537931
# 8          0.478831        0.021047                9            0.521839
# 9          0.000000        0.000000               13            0.000000
# 10         0.478831        0.021047                9            0.521839
# 11         0.000000        0.000000               13            0.000000
# 12         0.755148        0.024990                1            0.843678
# 13         0.675858        0.047033                5            0.712644
# 14         0.755148        0.024990                1            0.843678
# 15         0.675858        0.047033                5            0.712644
#
#     split1_train_score  split2_train_score  split3_train_score  \
# 0             0.275862            0.221198            0.276498
# 1             0.000000            0.000000            0.000000
# 2             0.275862            0.221198            0.276498
# 3             0.000000            0.000000            0.000000
# 4             0.760920            0.776498            0.769585
# 5             0.593103            0.576037            0.587558
# 6             0.760920            0.776498            0.769585
# 7             0.593103            0.576037            0.587558
# 8             0.535632            0.520737            0.534562
# 9             0.000000            0.000000            0.000000
# 10            0.535632            0.520737            0.534562
# 11            0.000000            0.000000            0.000000
# 12            0.827586            0.838710            0.861751
# 13            0.717241            0.707373            0.744240
# 14            0.827586            0.838710            0.861751
# 15            0.717241            0.707373            0.744240
#
#     split4_train_score  mean_train_score  std_train_score
# 0             0.320276          0.260146         0.041189
# 1             0.000000          0.000000         0.000000
# 2             0.320276          0.260146         0.041189
# 3             0.000000          0.000000         0.000000
# 4             0.778802          0.772563         0.006613
# 5             0.576037          0.574133         0.019277
# 6             0.778802          0.772563         0.006613
# 7             0.576037          0.574133         0.019277
# 8             0.552995          0.533153         0.011696
# 9             0.000000          0.000000         0.000000
# 10            0.552995          0.533153         0.011696
# 11            0.000000          0.000000         0.000000
# 12            0.847926          0.843930         0.011207
# 13            0.714286          0.719157         0.012945
# 14            0.847926          0.843930         0.011207
# 15            0.714286          0.719157         0.012945
#
# [16 rows x 25 columns]

# %%
eval_metric(svc_grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[241  12   7]
#  [ 16  97  23]
#  [ 16  97 645]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.93      0.90       260
#     Hispanic       0.47      0.71      0.57       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.85      1154
#    macro avg       0.77      0.83      0.79      1154
# weighted avg       0.88      0.85      0.86      1154
#
#
# Train_Set
# [[ 986   24   28]
#  [  23  458   62]
#  [  75  375 2584]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.95      0.93      1038
#     Hispanic       0.53      0.84      0.65       543
#        White       0.97      0.85      0.91      3034
#
#     accuracy                           0.87      4615
#    macro avg       0.80      0.88      0.83      4615
# weighted avg       0.90      0.87      0.88      4615

# %%
pd.DataFrame(svc_grid_model.cv_results_).loc[svc_grid_model.best_index_, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score     0.755148
# mean_train_score     0.84393
# Name: 12, dtype: object

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), remainder=StandardScaler())
operations = [("OneHot_Ordinal_Encoder", column_trans), ("SVC", SVC(C = 0.1, kernel = 'linear', class_weight = "balanced", random_state = 42))]
model = Pipeline(steps=operations)
scores = cross_validate(model, X_train, y_train, scoring = recall_hispanic, cv = 10,
                       return_train_score=True, n_jobs = -1)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_score     0.754714
# train_score    0.842844
# dtype: float64

# %%
decision_function = svc_grid_model.decision_function(X_test)
decision_function
# Out:
# array([[ 2.28915034,  1.11484949, -0.29202833],
#        [-0.27419934,  1.116871  ,  2.26793542],
#        [-0.27661736,  1.08856222,  2.27289674],
#        ...,
#        [ 2.29947285,  0.72698542, -0.27065453],
#        [-0.29188722,  0.85581577,  2.29547541],
#        [-0.27163189,  1.20386903,  2.24624761]])

# %%
svc_grid_model.predict(X_test)
# Out:
# array(['Black', 'White', 'White', ..., 'Black', 'White', 'White'],
#       dtype=object)

# %%
svc_grid_model.best_params_
# Out:
# {'SVC__C': 0.1,
#  'SVC__class_weight': 'balanced',
#  'SVC__degree': 2,
#  'SVC__gamma': 'scale',
#  'SVC__kernel': 'linear'}

# %%
plot_precision_recall(y_test, decision_function)
plt.show();

# %%
average_precision_score(y_test_dummies[:, 1], decision_function[:, 1])
# Out:
# 0.5959038906165952

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %%
from sklearn.ensemble import RandomForestClassifier

cat_ordinal = X_train.select_dtypes("object").columns.to_list()

column_trans = make_column_transformer((OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1), cat_ordinal), remainder="passthrough")
operations = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(random_state=42))]

pipe_model = Pipeline(steps=operations)

pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['gender',
#                                                    'subjectsbirthlocation',
#                                                    'writingpreference'])])),
#                 ('RF_model', RandomForestClassifier(random_state=42))])

# %%
eval_metric(pipe_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[199   4  57]
#  [  8  11 117]
#  [ 16   2 740]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.77      0.82       260
#     Hispanic       0.65      0.08      0.14       136
#        White       0.81      0.98      0.89       758
#
#     accuracy                           0.82      1154
#    macro avg       0.78      0.61      0.62      1154
# weighted avg       0.81      0.82      0.78      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %% [markdown]
# ## Cross Validation

# %%
operations = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", random_state=101))]

model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = recall_hispanic, 
                        cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_score     0.038586
# train_score    1.000000
# dtype: float64

# %%
pipe_model["RF_model"].feature_importances_
# Out:
# array([0.00579497, 0.0088313 , 0.00069827, 0.0054332 , 0.00969994,
#        0.00622149, 0.00783304, 0.00711283, 0.00572301, 0.00766089,
#        0.00662833, 0.00715803, 0.03255821, 0.00570469, 0.00536695,
#        0.02423659, 0.00785594, 0.00901931, 0.00659598, 0.00703593,
#        0.00909962, 0.01390492, 0.01615128, 0.00589064, 0.00709527,
#        0.0109899 , 0.00666941, 0.00622047, 0.00651769, 0.00852427,
#        0.00722499, 0.00688185, 0.0050478 , 0.01153137, 0.01084752,
#        0.02541607, 0.04406476, 0.00611139, 0.00808504, 0.01429525,
#        0.00690366, 0.00599113, 0.0215518 , 0.0063586 , 0.00624835,
#        0.00673143, 0.01918258, 0.00718072, 0.01476403, 0.00745836,
#        0.0062705 , 0.03651553, 0.00767187, 0.00668656, 0.00658796,
#        0.03721203, 0.00664242, 0.00623003, 0.00592368, 0.00630743,
#        0.00772267, 0.01309487, 0.00798427, 0.00687262, 0.00676256,
#        0.00724686, 0.00747835, 0.01431688, 0.00600114, 0.02184144,
#        0.00614594, 0.00682175, 0.00605905, 0.04414666, 0.00613542,
#        0.00691264, 0.01124313, 0.01273458, 0.00719342, 0.00662896,
#        0.01022676, 0.00697616, 0.00848215, 0.0061437 , 0.00804095,
#        0.00953932, 0.00913758, 0.01378053, 0.01313294, 0.00668922,
#        0.00529051, 0.00797961, 0.00627886, 0.00521383, 0.00860739,
#        0.01883095, 0.00614922])

# %%
features = pipe_model["OrdinalEncoder"].get_feature_names_out()
features
# Out:
# array(['ordinalencoder__gender', 'ordinalencoder__subjectsbirthlocation',
#        'ordinalencoder__writingpreference',
#        'remainder__abdominalextensiondepthsitting',
#        'remainder__acromialheight', 'remainder__acromionradialelength',
#        'remainder__anklecircumference', 'remainder__axillaheight',
#        'remainder__balloffootcircumference',
#        'remainder__balloffootlength', 'remainder__biacromialbreadth',
#        'remainder__bicepscircumferenceflexed',
#        'remainder__bicristalbreadth', 'remainder__bideltoidbreadth',
#        'remainder__bimalleolarbreadth', 'remainder__bitragionchinarc',
#        'remainder__bitragionsubmandibulararc',
#        'remainder__bizygomaticbreadth', 'remainder__buttockcircumference',
#        'remainder__buttockdepth', 'remainder__buttockheight',
#        'remainder__buttockkneelength',
#        'remainder__buttockpopliteallength',
#        'remainder__calfcircumference', 'remainder__cervicaleheight',
#        'remainder__chestbreadth', 'remainder__chestcircumference',
#        'remainder__chestdepth', 'remainder__chestheight',
#        'remainder__crotchheight', 'remainder__crotchlengthomphalion',
#        'remainder__crotchlengthposterioromphalion',
#        'remainder__earbreadth', 'remainder__earlength',
#        'remainder__earprotrusion', 'remainder__elbowrestheight',
#        'remainder__eyeheightsitting', 'remainder__footbreadthhorizontal',
#        'remainder__footlength', 'remainder__forearmcenterofgriplength',
#        'remainder__forearmcircumferenceflexed',
#        'remainder__forearmforearmbreadth', 'remainder__forearmhandlength',
#        'remainder__functionalleglength', 'remainder__handbreadth',
#        'remainder__handcircumference', 'remainder__handlength',
#        'remainder__headbreadth', 'remainder__headcircumference',
#        'remainder__headlength', 'remainder__heelanklecircumference',
#        'remainder__heelbreadth', 'remainder__hipbreadth',
#        'remainder__hipbreadthsitting', 'remainder__iliocristaleheight',
#        'remainder__interpupillarybreadth', 'remainder__interscyei',
#        'remainder__interscyeii', 'remainder__kneeheightmidpatella',
#        'remainder__kneeheightsitting',
#        'remainder__lateralfemoralepicondyleheight',
#        'remainder__lateralmalleolusheight',
#        'remainder__lowerthighcircumference',
#        'remainder__mentonsellionlength', 'remainder__neckcircumference',
#        'remainder__neckcircumferencebase',
#        'remainder__overheadfingertipreachsitting',
#        'remainder__palmlength', 'remainder__poplitealheight',
#        'remainder__radialestylionlength',
#        'remainder__shouldercircumference',
#        'remainder__shoulderelbowlength', 'remainder__shoulderlength',
#        'remainder__sittingheight', 'remainder__sleevelengthspinewrist',
#        'remainder__sleeveoutseam', 'remainder__span',
#        'remainder__stature', 'remainder__suprasternaleheight',
#        'remainder__tenthribheight', 'remainder__thighcircumference',
#        'remainder__thighclearance', 'remainder__thumbtipreach',
#        'remainder__tibialheight', 'remainder__tragiontopofhead',
#        'remainder__trochanterionheight',
#        'remainder__verticaltrunkcircumferenceusa',
#        'remainder__waistbacklength', 'remainder__waistbreadth',
#        'remainder__waistcircumference', 'remainder__waistdepth',
#        'remainder__waistfrontlengthsitting',
#        'remainder__waistheightomphalion', 'remainder__weightkg',
#        'remainder__wristcircumference', 'remainder__wristheight',
#        'remainder__age'], dtype=object)

# %%
new_features = [i.replace("ordinalencoder__","").replace("remainder__", "") for i in features]
new_features
# Out:
# ['gender',
#  'subjectsbirthlocation',
#  'writingpreference',
#  'abdominalextensiondepthsitting',
#  'acromialheight',
#  'acromionradialelength',
#  'anklecircumference',
#  'axillaheight',
#  'balloffootcircumference',
#  'balloffootlength',
#  'biacromialbreadth',
#  'bicepscircumferenceflexed',
#  'bicristalbreadth',
#  'bideltoidbreadth',
#  'bimalleolarbreadth',
#  'bitragionchinarc',
#  'bitragionsubmandibulararc',
#  'bizygomaticbreadth',
#  'buttockcircumference',
#  'buttockdepth',
#  'buttockheight',
#  'buttockkneelength',
#  'buttockpopliteallength',
#  'calfcircumference',
#  'cervicaleheight',
#  'chestbreadth',
#  'chestcircumference',
#  'chestdepth',
#  'chestheight',
#  'crotchheight',
#  'crotchlengthomphalion',
#  'crotchlengthposterioromphalion',
#  'earbreadth',
#  'earlength',
#  'earprotrusion',
#  'elbowrestheight',
#  'eyeheightsitting',
#  'footbreadthhorizontal',
#  'footlength',
#  'forearmcenterofgriplength',
#  'forearmcircumferenceflexed',
#  'forearmforearmbreadth',
#  'forearmhandlength',
#  'functionalleglength',
#  'handbreadth',
#  'handcircumference',
#  'handlength',
#  'headbreadth',
#  'headcircumference',
#  'headlength',
#  'heelanklecircumference',
#  'heelbreadth',
#  'hipbreadth',
#  'hipbreadthsitting',
#  'iliocristaleheight',
#  'interpupillarybreadth',
#  'interscyei',
#  'interscyeii',
#  'kneeheightmidpatella',
#  'kneeheightsitting',
#  'lateralfemoralepicondyleheight',
#  'lateralmalleolusheight',
#  'lowerthighcircumference',
#  'mentonsellionlength',
#  'neckcircumference',
#  'neckcircumferencebase',
#  'overheadfingertipreachsitting',
#  'palmlength',
#  'poplitealheight',
#  'radialestylionlength',
#  'shouldercircumference',
#  'shoulderelbowlength',
#  'shoulderlength',
#  'sittingheight',
#  'sleevelengthspinewrist',
#  'sleeveoutseam',
#  'span',
#  'stature',
#  'suprasternaleheight',
#  'tenthribheight',
#  'thighcircumference',
#  'thighclearance',
#  'thumbtipreach',
#  'tibialheight',
#  'tragiontopofhead',
#  'trochanterionheight',
#  'verticaltrunkcircumferenceusa',
#  'waistbacklength',
#  'waistbreadth',
#  'waistcircumference',
#  'waistdepth',
#  'waistfrontlengthsitting',
#  'waistheightomphalion',
#  'weightkg',
#  'wristcircumference',
#  'wristheight',
#  'age']

# %%
rf_feature_imp = pd.DataFrame(data = pipe_model["RF_model"].feature_importances_, index = new_features, #index=X.columns
                              columns = ["Feature Importance"])

rf_feature_imp = rf_feature_imp.sort_values("Feature Importance", ascending = False)
rf_feature_imp
# Out:
#                        Feature Importance
# sittingheight                    0.044147
# eyeheightsitting                 0.044065
# interpupillarybreadth            0.037212
# heelbreadth                      0.036516
# bicristalbreadth                 0.032558
# ...                                   ...
# bimalleolarbreadth               0.005367
# waistdepth                       0.005291
# weightkg                         0.005214
# earbreadth                       0.005048
# writingpreference                0.000698
#
# [97 rows x 1 columns]

# %%
ax = sns.barplot(x=rf_feature_imp["Feature Importance"], y=rf_feature_imp.index)
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.title("Feature Importance for Random Forest")
plt.show()

# %% [markdown]
# ### RF Model GridsearchCV

# %%
column_trans = make_column_transformer((OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1), cat_ordinal), remainder="passthrough")
operations = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", random_state=101))]

pipe_model = Pipeline(steps=operations)

param_grid = {'RF_model__n_estimators':[128, 200, 400, 500],
             'RF_model__max_features':[2, 4, 'sqrt'],
             'RF_model__max_depth':[2, 3, 4],
             'RF_model__max_samples':[0.8]} 

rf_grid_model = GridSearchCV(pipe_model, param_grid, scoring = recall_hispanic, cv = 5, return_train_score = True, n_jobs = -1, verbose=3).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %%
rf_grid_model.best_params_
# Out:
# {'RF_model__max_depth': 2,
#  'RF_model__max_features': 2,
#  'RF_model__max_samples': 0.8,
#  'RF_model__n_estimators': 500}

# %%
rf_grid_model.best_index_
# Out:
# 3

# %%
pd.DataFrame(rf_grid_model.cv_results_).loc[7, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score     0.659208
# mean_train_score    0.699796
# Name: 7, dtype: object

# %%
rf_grid_model.best_score_
# Out:
# 0.6647468569486918

# %%
eval_metric(rf_grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[161  67  32]
#  [  8  96  32]
#  [ 51 325 382]]
#               precision    recall  f1-score   support
#
#        Black       0.73      0.62      0.67       260
#     Hispanic       0.20      0.71      0.31       136
#        White       0.86      0.50      0.63       758
#
#     accuracy                           0.55      1154
#    macro avg       0.60      0.61      0.54      1154
# weighted avg       0.75      0.55      0.60      1154
#
#
# Train_Set
# [[ 659  277  102]
#  [  30  384  129]
#  [ 178 1327 1529]]
#               precision    recall  f1-score   support
#
#        Black       0.76      0.63      0.69      1038
#     Hispanic       0.19      0.71      0.30       543
#        White       0.87      0.50      0.64      3034
#
#     accuracy                           0.56      4615
#    macro avg       0.61      0.62      0.54      4615
# weighted avg       0.76      0.56      0.61      4615

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
import xgboost as xgb
from xgboost import XGBClassifier

# %%
operations_xgb = [("OrdinalEncoder", column_trans), 
                  ("XGB_model", XGBClassifier(random_state=101))]

pipe_model_xgb = Pipeline(steps=operations_xgb)

y_train_xgb = y_train.map({"Black":0, "Hispanic":1, "White":2}) 
y_test_xgb = y_test.map({"Black":0, "Hispanic":1, "White":2})



pipe_model_xgb.fit(X_train, y_train_xgb)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['gender',
#                                                    'subjectsbirthlocation',
#                                                    'writingpreference'])])),
#                 ('XGB_model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None...
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, n_estimators=100,
#                                n_jobs=None, num_parallel_tree=None,
#                                objective='multi:softprob', predictor=None, ...))])

# %%
eval_metric(pipe_model_xgb, X_train, y_train_xgb, X_test, y_test_xgb)
# Out:
# Test_Set
# [[227   1  32]
#  [  7  51  78]
#  [ 11  15 732]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       260
#            1       0.76      0.38      0.50       136
#            2       0.87      0.97      0.92       758
#
#     accuracy                           0.88      1154
#    macro avg       0.85      0.74      0.77      1154
# weighted avg       0.87      0.88      0.86      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1038
#            1       1.00      1.00      1.00       543
#            2       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %%
from sklearn.utils import class_weight
class_weights = class_weight.compute_sample_weight(class_weight='balanced', 
                                                     y=y_train_xgb)
class_weights
# Out:
# array([0.50703142, 0.50703142, 0.50703142, ..., 0.50703142, 0.50703142,
#        0.50703142])

# %%
comp = pd.DataFrame(class_weights, columns=["weights"], index = y_train.index)

comp["label"] = y_train
comp.head()
# Out:
#        weights  label
# 5204  0.507031  White
# 5393  0.507031  White
# 5528  0.507031  White
# 3861  0.507031  White
# 3205  0.507031  White

# %%
comp.groupby("label")["weights"].value_counts()
# Out:
# label     weights
# Black     1.482017    1038
# Hispanic  2.833026     543
# White     0.507031    3034
# Name: weights, dtype: int64

# %%
pipe_model_xgb.fit(X_train,
                   y_train_xgb,  
                   XGB_model__sample_weight=class_weights)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['gender',
#                                                    'subjectsbirthlocation',
#                                                    'writingpreference'])])),
#                 ('XGB_model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None...
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, n_estimators=100,
#                                n_jobs=None, num_parallel_tree=None,
#                                objective='multi:softprob', predictor=None, ...))])

# %%
eval_metric(pipe_model_xgb, X_train, y_train_xgb, X_test, y_test_xgb)
# Out:
# Test_Set
# [[229   3  28]
#  [ 10  61  65]
#  [ 17  28 713]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.89       260
#            1       0.66      0.45      0.54       136
#            2       0.88      0.94      0.91       758
#
#     accuracy                           0.87      1154
#    macro avg       0.81      0.76      0.78      1154
# weighted avg       0.86      0.87      0.86      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1038
#            1       1.00      1.00      1.00       543
#            2       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %%
scoring_xgb = {"precision_Hispanic" : make_scorer(precision_score, average = None, labels =[1]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =[1]),
           "f1_Hispanic" : make_scorer(f1_score, average = None, labels =[1])}

# %%
operations_xgb = [("OrdinalEncoder", column_trans), 
                  ("XGB_model", XGBClassifier(random_state=101))]

model = Pipeline(steps=operations_xgb)

scores = cross_validate(model, 
                        X_train, 
                        y_train_xgb, 
                        scoring=scoring_xgb,
                        cv=5, 
                        return_train_score=True,
                        fit_params={"XGB_model__sample_weight":class_weights})
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_precision_Hispanic     0.712584
# train_precision_Hispanic    1.000000
# test_recall_Hispanic        0.441981
# train_recall_Hispanic       1.000000
# test_f1_Hispanic            0.544594
# train_f1_Hispanic           1.000000
# dtype: float64

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
param_grid = {"XGB_model__n_estimators":[20, 40],
              'XGB_model__max_depth':[1,2],
              "XGB_model__learning_rate": [0.02, 0.05],
              "XGB_model__subsample":[0.8, 1],
              "XGB_model__colsample_bytree":[0.8, 1]}

# %%
operations_xgb = [("OrdinalEncoder", column_trans),
                  ("XGB_model", XGBClassifier(random_state=101))]

model = Pipeline(steps=operations_xgb)

xgb_grid_model = GridSearchCV(model, 
                              param_grid, 
                              scoring=make_scorer(recall_score, average = None, labels =[1]),
                              cv=5,
                              n_jobs=-1,
                              return_train_score=True)

# %%
xgb_grid_model.fit(X_train,
                   y_train_xgb,
                   XGB_model__sample_weight=class_weights)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['gender',
#                                                                           'subjectsbirthlocation',
#                                                                           'writingpreference'])])),
#                                        ('XGB_model',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_byleve...
#                                                       n_jobs=None,
#                                                       num_parallel_tree=None,
#                                                       predictor=None,
#                                                       random_state=101, ...))]),
#              n_jobs=-1,
#              param_grid={'XGB_model__colsample_bytree': [0.8, 1],
#                          'XGB_model__learning_rate': [0.02, 0.05],
#                          'XGB_model__max_depth': [1, 2],
#                          'XGB_model__n_estimators': [20, 40],
#                          'XGB_model__subsample': [0.8, 1]},
#              return_train_score=True,
#              scoring=make_scorer(recall_score, average=None, labels=[1]))

# %%
xgb_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['gender',
#                                                    'subjectsbirthlocation',
#                                                    'writingpreference'])])),
#                 ('XGB_model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None...
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=2, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, n_estimators=40,
#                                n_jobs=None, num_parallel_tree=None,
#                                objective='multi:softprob', predictor=None, ...))])

# %%
xgb_grid_model.best_params_
# Out:
# {'XGB_model__colsample_bytree': 0.8,
#  'XGB_model__learning_rate': 0.05,
#  'XGB_model__max_depth': 2,
#  'XGB_model__n_estimators': 40,
#  'XGB_model__subsample': 0.8}

# %%
pd.DataFrame(xgb_grid_model.cv_results_).loc[xgb_grid_model.best_index_, ["mean_test_score", "mean_train_score"]]
# Out:
# mean_test_score      0.59842
# mean_train_score    0.648253
# Name: 14, dtype: object

# %%
xgb_grid_model.best_score_
# Out:
# 0.5984199796126402

# %%
eval_metric(xgb_grid_model, X_train, y_train_xgb, X_test, y_test_xgb)
# Out:
# Test_Set
# [[201  37  22]
#  [ 18  78  40]
#  [ 79 195 484]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.77      0.72       260
#            1       0.25      0.57      0.35       136
#            2       0.89      0.64      0.74       758
#
#     accuracy                           0.66      1154
#    macro avg       0.60      0.66      0.60      1154
# weighted avg       0.76      0.66      0.69      1154
#
#
# Train_Set
# [[ 805  153   80]
#  [  70  346  127]
#  [ 272  744 2018]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.78      0.74      1038
#            1       0.28      0.64      0.39       543
#            2       0.91      0.67      0.77      3034
#
#     accuracy                           0.69      4615
#    macro avg       0.63      0.69      0.63      4615
# weighted avg       0.79      0.69      0.72      4615

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve


operations_xgb = [("OrdinalEncoder", column_trans), 
                  ("XGB_model", XGBClassifier(colsample_bytree=0.8,
                                              learning_rate=0.05,
                                              max_depth=2,
                                              n_estimators=20,
                                              subsample=0.8,
                                              random_state=101))]

model = Pipeline(steps=operations_xgb)

model.fit(X_train, 
          y_train_xgb, 
          XGB_model__sample_weight=class_weights)

y_pred_proba = model.predict_proba(X_test)
    
plot_precision_recall(y_test_xgb, y_pred_proba)
plt.show()

# %%
y_test_xgb_dummies = pd.get_dummies(y_test_xgb).values

# %%
average_precision_score(y_test_xgb_dummies[:, 1], y_pred_proba[:, 1])
# Out:
# 0.33845910735146734

# %%
y_pred = xgb_grid_model.predict(X_test)

xgb_AP = average_precision_score(y_test_xgb_dummies[:, 1], y_pred_proba[:, 1])
xgb_f1 = f1_score(y_test_xgb, y_pred, average=None, labels=[1])
xgb_recall = recall_score(y_test_xgb, y_pred, average=None, labels=[1])

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", 
                                                      sparse=False), cat), 
                                       remainder=MinMaxScaler())

# %%
X_train_ohe = column_trans.fit_transform(X_train)

# %%
over = SMOTE()
X_train_over, y_train_over = over.fit_resample(X_train_ohe, y_train)

# %%
X_train_over.shape
# Out:
# (9102, 225)

# %%
y_train_over.value_counts()
# Out:
# White       3034
# Black       3034
# Hispanic    3034
# Name: dodrace, dtype: int64

# %%
under = RandomUnderSampler()
X_train_under, y_train_under = under.fit_resample(X_train_ohe, y_train)

# %%
X_train_under.shape
# Out:
# (1629, 225)

# %%
y_train_under.value_counts()
# Out:
# Black       543
# Hispanic    543
# White       543
# Name: dodrace, dtype: int64

# %%
over = SMOTE(sampling_strategy={"Hispanic": 1000})
under = RandomUnderSampler(sampling_strategy={"White": 2500})

# %%
y_train.value_counts()
# Out:
# White       3034
# Black       1038
# Hispanic     543
# Name: dodrace, dtype: int64

# %%
X_resampled_over, y_resampled_over = over.fit_resample(X_train_ohe, y_train)

# %%
y_resampled_over.value_counts()
# Out:
# White       3034
# Black       1038
# Hispanic    1000
# Name: dodrace, dtype: int64

# %%
X_resampled_under, y_resampled_under = under.fit_resample(X_train_ohe, y_train)

# %%
y_resampled_under.value_counts()
# Out:
# White       2500
# Black       1038
# Hispanic     543
# Name: dodrace, dtype: int64

# %%
steps = [('o', over), ('u', under)]
pipeline = imbpipeline(steps=steps)
X_resampled, y_resampled = pipeline.fit_resample(X_train_ohe, y_train)

# %%
y_resampled.value_counts()
# Out:
# White       2500
# Black       1038
# Hispanic    1000
# Name: dodrace, dtype: int64

# %%
y_train.value_counts()
# Out:
# White       3034
# Black       1038
# Hispanic     543
# Name: dodrace, dtype: int64

# %% [markdown]
# ## SVC Over/Under Sampling

# %%
over = SMOTE(sampling_strategy={"Hispanic": 1000})
under = RandomUnderSampler(sampling_strategy={"White": 2500})

column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), remainder=StandardScaler())
operations = [("OneHotEncoder",column_trans), ('o', over), ('u', under), 
              ("SVC", SVC(C = 0.01, kernel = 'linear', random_state = 101))]
smote_pipeline = imbpipeline(steps=operations)
smote_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=StandardScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['gender', 'subjectsbirthlocation', 'writingpreference'], dtype='object'))])),
#                 ('o', SMOTE(sampling_strategy={'Hispanic': 1000})),
#                 ('u', RandomUnderSampler(sampling_strategy={'White': 2500})),
#                 ('SVC', SVC(C=0.01, kernel='linear', random_state=101))])

# %%
eval_metric(smote_pipeline, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[240  10  10]
#  [ 14  76  46]
#  [  7  40 711]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.92      0.92       260
#     Hispanic       0.60      0.56      0.58       136
#        White       0.93      0.94      0.93       758
#
#     accuracy                           0.89      1154
#    macro avg       0.82      0.81      0.81      1154
# weighted avg       0.89      0.89      0.89      1154
#
#
# Train_Set
# [[ 933   32   73]
#  [  33  325  185]
#  [  39  151 2844]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.90      0.91      1038
#     Hispanic       0.64      0.60      0.62       543
#        White       0.92      0.94      0.93      3034
#
#     accuracy                           0.89      4615
#    macro avg       0.83      0.81      0.82      4615
# weighted avg       0.89      0.89      0.89      4615

# %%
scoring = {"precision_Hispanic" : make_scorer(precision_score, average = None, labels =["Hispanic"]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =["Hispanic"]),
           "f1_Hispanic" : make_scorer(f1_score, average = None, labels =["Hispanic"])}

model = imbpipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_precision_Hispanic     0.617207
# train_precision_Hispanic    0.646937
# test_recall_Hispanic        0.545051
# train_recall_Hispanic       0.595046
# test_f1_Hispanic            0.578340
# train_f1_Hispanic           0.619792
# dtype: float64

# %% [markdown]
# #  SHAP
#
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
column_trans_shap = make_column_transformer((OneHotEncoder(handle_unknown="ignore",
                                                           sparse=False), cat), 
                                             remainder=MinMaxScaler(),
                                             verbose_feature_names_out=False)

X_train_trans = column_trans_shap.fit_transform(X_train)
X_test_trans = column_trans_shap.transform(X_test)

model_shap = LogisticRegression(class_weight='balanced',
                                max_iter=10000,
                                random_state=101,
                                penalty="l1",
                                solver='saga')

model_shap.fit(X_train_trans, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=10000, penalty='l1',
#                    random_state=101, solver='saga')

# %%
eval_metric(model_shap, X_train_trans, y_train, X_test_trans, y_test)
# Out:
# Test_Set
# [[241  12   7]
#  [ 15 102  19]
#  [ 13 101 644]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.93      0.91       260
#     Hispanic       0.47      0.75      0.58       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.78      0.84      0.80      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 974   32   32]
#  [  15  463   65]
#  [  75  351 2608]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.94      0.93      1038
#     Hispanic       0.55      0.85      0.67       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.90      0.88      0.88      4615

# %%
operations = [("OneHotEncoder", column_trans_shap),
              ("log", LogisticRegression(class_weight='balanced',
                                         max_iter=10000,
                                         random_state=101,
                                         penalty="l1",
                                         solver='saga'))]

model = Pipeline(steps=operations)

scores = cross_validate(model,
                        X_train,
                        y_train, 
                        scoring=scoring,
                        cv=5,
                        return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_precision_Hispanic     0.507266
# train_precision_Hispanic    0.548297
# test_recall_Hispanic        0.773564
# train_recall_Hispanic       0.852678
# test_f1_Hispanic            0.612267
# train_f1_Hispanic           0.667371
# dtype: float64

# %%
features = column_trans_shap.get_feature_names_out()
features
# Out:
# array(['gender_Female', 'gender_Male', 'subjectsbirthlocation_Alabama',
#        'subjectsbirthlocation_Alaska',
#        'subjectsbirthlocation_Antigua and Barbuda',
#        'subjectsbirthlocation_Arizona', 'subjectsbirthlocation_Arkansas',
#        'subjectsbirthlocation_Azerbaijan',
#        'subjectsbirthlocation_Barbados', 'subjectsbirthlocation_Belarus',
#        'subjectsbirthlocation_Belgium', 'subjectsbirthlocation_Belize',
#        'subjectsbirthlocation_Bermuda', 'subjectsbirthlocation_Bolivia',
#        'subjectsbirthlocation_Bosnia and Herzegovina',
#        'subjectsbirthlocation_British Virgin Islands',
#        'subjectsbirthlocation_Bulgaria',
#        'subjectsbirthlocation_California',
#        'subjectsbirthlocation_Cameroon', 'subjectsbirthlocation_Canada',
#        'subjectsbirthlocation_Cape Verde',
#        'subjectsbirthlocation_Colombia', 'subjectsbirthlocation_Colorado',
#        'subjectsbirthlocation_Connecticut',
#        'subjectsbirthlocation_Costa Rica', 'subjectsbirthlocation_Cuba',
#        'subjectsbirthlocation_Delaware', 'subjectsbirthlocation_Denmark',
#        'subjectsbirthlocation_District of Columbia',
#        'subjectsbirthlocation_Dominica',
#        'subjectsbirthlocation_Dominican Republic',
#        'subjectsbirthlocation_Ecuador', 'subjectsbirthlocation_Egypt',
#        'subjectsbirthlocation_El Salvador',
#        'subjectsbirthlocation_Ethiopia', 'subjectsbirthlocation_Florida',
#        'subjectsbirthlocation_France',
#        'subjectsbirthlocation_French Guiana',
#        'subjectsbirthlocation_Georgia', 'subjectsbirthlocation_Germany',
#        'subjectsbirthlocation_Ghana', 'subjectsbirthlocation_Grenada',
#        'subjectsbirthlocation_Guam', 'subjectsbirthlocation_Guatemala',
#        'subjectsbirthlocation_Guyana', 'subjectsbirthlocation_Haiti',
#        'subjectsbirthlocation_Hawaii', 'subjectsbirthlocation_Honduras',
#        'subjectsbirthlocation_Idaho', 'subjectsbirthlocation_Illinois',
#        'subjectsbirthlocation_India', 'subjectsbirthlocation_Indiana',
#        'subjectsbirthlocation_Iowa', 'subjectsbirthlocation_Iran',
#        'subjectsbirthlocation_Iraq', 'subjectsbirthlocation_Israel',
#        'subjectsbirthlocation_Italy', 'subjectsbirthlocation_Jamaica',
#        'subjectsbirthlocation_Japan', 'subjectsbirthlocation_Kansas',
#        'subjectsbirthlocation_Kentucky', 'subjectsbirthlocation_Kenya',
#        'subjectsbirthlocation_Lebanon', 'subjectsbirthlocation_Liberia',
#        'subjectsbirthlocation_Louisiana', 'subjectsbirthlocation_Maine',
#        'subjectsbirthlocation_Maryland',
#        'subjectsbirthlocation_Massachusetts',
#        'subjectsbirthlocation_Mexico', 'subjectsbirthlocation_Michigan',
#        'subjectsbirthlocation_Minnesota',
#        'subjectsbirthlocation_Mississippi',
#        'subjectsbirthlocation_Missouri', 'subjectsbirthlocation_Montana',
#        'subjectsbirthlocation_Morocco', 'subjectsbirthlocation_Nebraska',
#        'subjectsbirthlocation_Netherlands',
#        'subjectsbirthlocation_Nevada',
#        'subjectsbirthlocation_New Hampshire',
#        'subjectsbirthlocation_New Jersey',
#        'subjectsbirthlocation_New Mexico',
#        'subjectsbirthlocation_New York',
#        'subjectsbirthlocation_New Zealand',
#        'subjectsbirthlocation_Nicaragua', 'subjectsbirthlocation_Nigeria',
#        'subjectsbirthlocation_North Carolina',
#        'subjectsbirthlocation_North Dakota', 'subjectsbirthlocation_Ohio',
#        'subjectsbirthlocation_Oklahoma', 'subjectsbirthlocation_Oregon',
#        'subjectsbirthlocation_Panama', 'subjectsbirthlocation_Paraguay',
#        'subjectsbirthlocation_Pennsylvania', 'subjectsbirthlocation_Peru',
#        'subjectsbirthlocation_Philippines',
#        'subjectsbirthlocation_Poland', 'subjectsbirthlocation_Portugal',
#        'subjectsbirthlocation_Puerto Rico',
#        'subjectsbirthlocation_Rhode Island',
#        'subjectsbirthlocation_Romania', 'subjectsbirthlocation_Russia',
#        'subjectsbirthlocation_Saint Lucia',
#        'subjectsbirthlocation_Serbia',
#        'subjectsbirthlocation_Sierra Leone',
#        'subjectsbirthlocation_South Africa',
#        'subjectsbirthlocation_South America',
#        'subjectsbirthlocation_South Carolina',
#        'subjectsbirthlocation_South Dakota',
#        'subjectsbirthlocation_South Korea',
#        'subjectsbirthlocation_Sri Lanka', 'subjectsbirthlocation_Sudan',
#        'subjectsbirthlocation_Syria', 'subjectsbirthlocation_Tennessee',
#        'subjectsbirthlocation_Texas', 'subjectsbirthlocation_Togo',
#        'subjectsbirthlocation_Trinidad and Tobago',
#        'subjectsbirthlocation_Turkey',
#        'subjectsbirthlocation_US Virgin Islands',
#        'subjectsbirthlocation_Ukraine',
#        'subjectsbirthlocation_United Kingdom',
#        'subjectsbirthlocation_United States',
#        'subjectsbirthlocation_Utah', 'subjectsbirthlocation_Vermont',
#        'subjectsbirthlocation_Virginia',
#        'subjectsbirthlocation_Washington',
#        'subjectsbirthlocation_West Virginia',
#        'subjectsbirthlocation_Wisconsin', 'subjectsbirthlocation_Wyoming',
#        'writingpreference_Either hand (No preference)',
#        'writingpreference_Left hand', 'writingpreference_Right hand',
#        'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed', 'bicristalbreadth',
#        'bideltoidbreadth', 'bimalleolarbreadth', 'bitragionchinarc',
#        'bitragionsubmandibulararc', 'bizygomaticbreadth',
#        'buttockcircumference', 'buttockdepth', 'buttockheight',
#        'buttockkneelength', 'buttockpopliteallength', 'calfcircumference',
#        'cervicaleheight', 'chestbreadth', 'chestcircumference',
#        'chestdepth', 'chestheight', 'crotchheight',
#        'crotchlengthomphalion', 'crotchlengthposterioromphalion',
#        'earbreadth', 'earlength', 'earprotrusion', 'elbowrestheight',
#        'eyeheightsitting', 'footbreadthhorizontal', 'footlength',
#        'forearmcenterofgriplength', 'forearmcircumferenceflexed',
#        'forearmforearmbreadth', 'forearmhandlength',
#        'functionalleglength', 'handbreadth', 'handcircumference',
#        'handlength', 'headbreadth', 'headcircumference', 'headlength',
#        'heelanklecircumference', 'heelbreadth', 'hipbreadth',
#        'hipbreadthsitting', 'iliocristaleheight', 'interpupillarybreadth',
#        'interscyei', 'interscyeii', 'kneeheightmidpatella',
#        'kneeheightsitting', 'lateralfemoralepicondyleheight',
#        'lateralmalleolusheight', 'lowerthighcircumference',
#        'mentonsellionlength', 'neckcircumference',
#        'neckcircumferencebase', 'overheadfingertipreachsitting',
#        'palmlength', 'poplitealheight', 'radialestylionlength',
#        'shouldercircumference', 'shoulderelbowlength', 'shoulderlength',
#        'sittingheight', 'sleevelengthspinewrist', 'sleeveoutseam', 'span',
#        'stature', 'suprasternaleheight', 'tenthribheight',
#        'thighcircumference', 'thighclearance', 'thumbtipreach',
#        'tibialheight', 'tragiontopofhead', 'trochanterionheight',
#        'verticaltrunkcircumferenceusa', 'waistbacklength', 'waistbreadth',
#        'waistcircumference', 'waistdepth', 'waistfrontlengthsitting',
#        'waistheightomphalion', 'weightkg', 'wristcircumference',
#        'wristheight', 'age'], dtype=object)

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %% [markdown]
# ## Comparing Models

# %%
y_pred = grid_model.predict(X_test)

log_AP = average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
log_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
log_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %%
y_pred = xgb_grid_model.predict(X_test)

xgb_AP = average_precision_score(y_test_xgb_dummies[:, 1], y_pred_proba[:, 1])
xgb_f1 = f1_score(y_test_xgb, y_pred, average=None, labels=[1])
xgb_recall = recall_score(y_test_xgb, y_pred, average=None, labels=[1])

# %%
y_pred = svc_grid_model.predict(X_test)

svc_AP = average_precision_score(y_test_dummies[:, 1], decision_function[:, 1])
svc_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
svc_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %%
y_pred = rf_grid_model.predict(X_test)

rf_AP = average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
rf_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
rf_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %%
compare = pd.DataFrame({"Model": ["Logistic Regression", "SVM",  "Random Forest", "XGBoost"],
                        "F1": [log_f1[0], svc_f1[0], rf_f1[0], xgb_f1[0]],
                        "Recall": [log_recall[0], svc_recall[0], rf_recall[0], xgb_recall[0]],
                        "AP": [log_AP, svc_AP, rf_AP, xgb_AP]})

    
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(313)
compare = compare.sort_values(by="AP", ascending=False)
ax=sns.barplot(x="AP", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.show();

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=8, stratify = y)

# %%
cat_onehot = X_train.select_dtypes("object").columns.to_list()
olumn_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat_onehot), remainder=StandardScaler())

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
operations = [("OneHotEncoder", column_trans), ("svc", SVC(C = 0.01, kernel = 'linear', class_weight = "balanced", random_state = 101))]

model = Pipeline(steps=operations)

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=StandardScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['gender', 'subjectsbirthlocation', 'writingpreference'], dtype='object'))])),
#                 ('svc',
#                  SVC(C=0.01, class_weight='balanced', kernel='linear',
#                      random_state=101))])

# %%
X[X.gender=="Male"].describe()
# Out:
#        abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# count                     3899.000000     3899.000000            3899.000000
# mean                       255.449090     1442.946397             335.819441
# std                         37.295117       62.356906              17.281413
# min                        163.000000     1194.000000             270.000000
# 25%                        228.000000     1401.000000             324.000000
# 50%                        252.000000     1441.000000             335.000000
# 75%                        280.000000     1483.000000             347.000000
# max                        451.000000     1683.000000             393.000000
#
#        anklecircumference  axillaheight  balloffootcircumference  \
# count         3899.000000   3899.000000               3899.00000
# mean           229.590921   1331.098487                252.16594
# std             14.579399     58.714251                 12.89351
# min            156.000000   1106.000000                186.00000
# 25%            220.000000   1291.000000                244.00000
# 50%            229.000000   1330.000000                252.00000
# 75%            239.000000   1368.000000                261.00000
# max            293.000000   1553.000000                306.00000
#
#        balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# count       3899.000000        3899.000000                3899.000000
# mean         201.229546         416.004360                 358.579636
# std           10.329358          19.074837                  34.511924
# min          156.000000         337.000000                 246.000000
# 25%          194.000000         403.000000                 335.000000
# 50%          201.000000         415.000000                 358.000000
# 75%          208.000000         428.000000                 380.000000
# max          245.000000         489.000000                 490.000000
#
#        bicristalbreadth  ...  waistbacklength  waistbreadth  \
# count       3899.000000  ...      3899.000000   3899.000000
# mean         275.632213  ...       478.017953    327.110798
# std           17.512428  ...        27.662347     34.680178
# min          219.000000  ...       383.000000    232.000000
# 25%          263.000000  ...       460.000000    301.000000
# 50%          275.000000  ...       477.000000    326.000000
# 75%          288.000000  ...       495.000000    351.000000
# max          334.000000  ...       598.000000    459.000000
#
#        waistcircumference   waistdepth  waistfrontlengthsitting  \
# count         3899.000000  3899.000000              3899.000000
# mean           943.043344   238.560400               388.017440
# std            111.463219    34.730231                29.360557
# min            648.000000   161.000000               293.000000
# 25%            859.000000   212.000000               368.000000
# 50%            940.000000   235.000000               387.000000
# 75%           1018.000000   261.000000               407.000000
# max           1379.000000   406.000000               494.000000
#
#        waistheightomphalion     weightkg  wristcircumference  wristheight  \
# count           3899.000000  3899.000000         3899.000000  3899.000000
# mean            1058.239805   858.714286          176.168761   848.762247
# std               51.599179   141.506945            8.855214    41.138763
# min              876.000000   393.000000          149.000000   695.000000
# 25%             1023.000000   760.000000          170.000000   820.000000
# 50%             1057.000000   849.000000          176.000000   848.000000
# 75%             1092.000000   947.000000          182.000000   875.000000
# max             1245.000000  1442.000000          216.000000  1009.000000
#
#                age
# count  3899.000000
# mean     30.172352
# std       8.835481
# min      18.000000
# 25%      23.000000
# 50%      28.000000
# 75%      36.500000
# max      58.000000
#
# [8 rows x 94 columns]

# %%
male_mean_human = X[X.gender=="Male"].describe(include="all").loc["mean"]
male_mean_human
# Out:
# abdominalextensiondepthsitting      255.44909
# acromialheight                    1442.946397
# acromionradialelength              335.819441
# anklecircumference                 229.590921
# axillaheight                      1331.098487
#                                      ...
# wristheight                        848.762247
# gender                                    NaN
# subjectsbirthlocation                     NaN
# age                                 30.172352
# writingpreference                         NaN
# Name: mean, Length: 97, dtype: object

# %%
male_mean_human["gender"] = "Male"
male_mean_human["subjectsbirthlocation"] = "Texas"
male_mean_human["writingpreference"] = "Right hand"

# %%
pd.DataFrame(male_mean_human).T
# Out:
#      abdominalextensiondepthsitting acromialheight acromionradialelength  \
# mean                      255.44909    1442.946397            335.819441
#
#      anklecircumference axillaheight balloffootcircumference balloffootlength  \
# mean         229.590921  1331.098487               252.16594       201.229546
#
#      biacromialbreadth bicepscircumferenceflexed bicristalbreadth  ...  \
# mean         416.00436                358.579636       275.632213  ...
#
#      waistdepth waistfrontlengthsitting waistheightomphalion    weightkg  \
# mean   238.5604               388.01744          1058.239805  858.714286
#
#      wristcircumference wristheight gender subjectsbirthlocation        age  \
# mean         176.168761  848.762247   Male                 Texas  30.172352
#
#      writingpreference
# mean        Right hand
#
# [1 rows x 97 columns]

# %%
model.predict(pd.DataFrame(male_mean_human).T)
# Out:
# array(['Hispanic'], dtype=object)

# %%
from sklearn.metrics import matthews_corrcoef

y_pred = model.predict(X_test)

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7554850143013702

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.751375592830192

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
